# %% [markdown]
# # 문장 평가
# - [잘 설명해준 사이트](https://jrc-park.tistory.com/273)
# - 생성된 문장을 평가하는 방식은 크게 2가지 (Reference가 Ground truth로 보면 되는 듯)
#   1. Rouge: Reference 문장의 단어가 Generated 문장에 포함되는 정도
#      - Text Summarization
#   2. **BLEU**: Generated 문장의 단어가 Reference Sentence에 포함되는 정도
#      - Machine Translation

# %% [markdown]
# ## 코드 예시

# %%
from nltk.translate.bleu_score import sentence_bleu
reference = [["this", "is", "the", "sample"]]
candidate = ['this', "is", "the", "sample"]
score1 = sentence_bleu(reference, candidate, weights=(1, 0, 0, 0)) # 1.0

score1
# Out:
# 1.0

# %% [markdown]
# # N-gram
# - 위 sentence_bleu 함수의 weights 인자에 들어가는것이 N-gram 인자이며 (1, 0, 0, 0)은 1-gram token들로만 평가를 진행한다는 의미
#   - 1-gram
#     - this, is, the, sample
#   - 2-gram
#     - this is, is the, the sample
#   - 3-gram
#     - this is the, is the sample
#   - 4-gram
#     - this is the sample
# - gram 수가 올라갈수록 **순서를 정확히 고려**해야 하므로 높은 점수를 받기가 쉽지 않아짐

# %%
import warnings
warnings.filterwarnings('ignore')

reference = [["나는", "너를", "사랑해", "정말로"]]
candidate = ["나는", "사랑해", "정말로", "너를"]
candidate_v2 = ["나는", "사랑해", "너를", "정말로"]
gram1 = sentence_bleu(reference, candidate, weights=(1, 0, 0, 0))
gram2 = sentence_bleu(reference, candidate, weights=(0, 1, 0, 0))
gram_v2 = sentence_bleu(reference, candidate_v2, weights=(0, 1, 0, 0)) # 1.0

print(f'1-gram score: {gram1}, 2-gram score: {gram2}, 2-gram_v2 score: {gram_v2}')
# Out:
# 1-gram score: 1.0, 2-gram score: 0.3333333333333333, 2-gram_v2 score: 2.2250738585072626e-308

# %% [markdown]
# - 2-gram의 경우 "사랑해", "정말로" 를 통해 2-gram 에 포함되어 있는 문장을 맞췄지만 2-gram_v2의 경우에는 그렇지 못해서 0 값(표기상으론 아주 작은값)을 받은 걸 알 수 있음

# %% [markdown]
# # Easy-OCR BLEU 기반 성능 테스트
# - 실시간으로 이미지를 계속 읽어와서 테스트를 진행하고자 한다

# %% [markdown]
# ## 영상 저장 코드

# %%
import datetime
import cv2

device_id = 1

capture = cv2.VideoCapture(device_id)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
record = False

while True:
    if(capture.get(cv2.CAP_PROP_POS_FRAMES) == capture.get(cv2.CAP_PROP_FRAME_COUNT)):
        capture.open(device_id)

    ret, frame = capture.read()
    cv2.imshow("VideoFrame", frame)

    now = datetime.datetime.now().strftime("%d_%H-%M-%S")
    key = cv2.waitKey(33)

    if key == 27:       # ESC
        break
    elif key == 26:     # Ctrl - Z
        print("캡쳐")
        cv2.imwrite("D:/" + str(now) + ".png", frame)
    elif key == 24:     # Ctrl - X
        print("녹화 시작")
        record = True
        video = cv2.VideoWriter("D:/" + str(now) + ".avi", fourcc, 20.0, (frame.shape[1], frame.shape[0]))
    elif key == 3:      # Ctrl - C
        print("녹화 중지")
        record = False
        video.release()
        
    if record == True:
        video.write(frame)

capture.release()
cv2.destroyAllWindows()
# Out:
# 녹화 시작

# %% [markdown]
# ## 성능 산출 코드

# %%
import easyocr
import cv2
import numpy as np
import warnings
import time
warnings.filterwarnings('ignore')
from nltk.translate.bleu_score import sentence_bleu

def BLEU_mean(source:str, ref:list):
    mean_val = 0
    count = 0
    # cam = cv2.VideoCapture(0)     # if you want to use webcam
    cam = cv2.VideoCapture(source)        # if you want to read video file
    reader = easyocr.Reader(['ko', 'en'], gpu=True)

    reference = [ref]

    while True:
        check,frame = cam.read()
        if not check:
            print("비디오 종료")
            break
        
        count += 1

        cv2.imshow('video', frame)
        result = reader.readtext(frame)
        # candidate = []

        if len(result) != 0:        # 뭔가 잡았다면
            text = []
            for obj in result:
                # bbox = obj[0]
                text.append(obj[1])
                # confidence = obj[2]
            bleu_score = sentence_bleu(reference, text, weights=(1, 0, 0, 0)) # 1.0
            
            if bleu_score != 0.0:       # 많은 예측값들 중 정답 단어를 예측한게 있다면
                mean_val += 1.0
            
            else:
                pass

            print(f"인식한 글자: {text}")
            
        key = cv2.waitKey(1)
        if key == 27:
            break

    cam.release()
    cv2.destroyAllWindows
    return mean_val / count, count

source = 'D:/15_20-33-53.avi'
ref = ['딱풀']
val, frames = BLEU_mean(source, ref)
print(f"Mean score of BLEU: {val}, Total Frame: {frames}")
# Out:
# 인식한 글자: ['Ao5', '으', "'따물", '초강터']
# 인식한 글자: ['MoS', '9', "'따물", '초강다']
# 인식한 글자: ['MeS', '9', "'따물", '초강다']
# 인식한 글자: ['Mo5', "'따물", '95', '초강다']
# 인식한 글자: ['Mo5', "'따물", '95', '초강터']
# 인식한 글자: ['Mo5', '드5', "'따물", '초강리']
# 인식한 글자: ['Mo5', '드5', "'따물", '초강터']
# 인식한 글자: ['A5', '드5', "'따물", '초강리']
# 인식한 글자: ['A', '9', "'따물", '초강리']
# 인식한 글자: ['M5', '9', "'따물", '초강리']
# 인식한 글자: ['Me5', "'따물", '초강적']
# 인식한 글자: ['Mo5', "'따물", '초강터']
# 인식한 글자: ['M5', '따물', '9', '초강리']
# 인식한 글자: ['Ae5', '우', '초강력', '딱풀']
# 인식한 글자: ['Me5', "'따물", '드', '초강리']
# 인식한 글자: ['45', '$', "'딱물", '초강되']
# 인식한 글자: ['M', '우', "'따물", '초강적']
# 인식한 글자: ['Mo5', '$', "'따물", '초강터']
# 인식한 글자: ['Mo5', '9', '딱풀', '초강디']
# 인식한 글자: ['Mo5', '93', "'따물", '초강리']
# 인식한 글자: ['Mo5', '9', "'", '딱물', '초강리']
# 인식한 글자: ['Mo5', '95', "'딱물", '초강터']
# 인식한 글자: ['Mo5', '9', "'따물", '초강터']
# 인식한 글자: ['4o5', '$', "'딱물", '초강터']
# 인식한 글자: ['Mo5', '9', 'S3', '따풀', '초강리']
# 인식한 글자: ['4o5', '도?', '딱물', '9', '초강터']
# 인식한 글자: ['4o5', 'S', "'따물", '초강리']
# 인식한 글자: ['MS', '9', '따물', '초강리']
# 인식한 글자: ['Mos', '따풀', '총강리']
# 인식한 글자: ['Mos', '드5', '따풀', '초강다']
# 인식한 글자: ['MS', '9', '따물', '초강다']
# 인식한 글자: ['Me5', '9', '따물', '초강다']
# 인식한 글자: ['4o5', '9', '따물', '초강다']
# 인식한 글자: ['4o5', 'S', '따풀', '초강적']
# 인식한 글자: ['45', 's', '"따물', '초강여']
# 인식한 글자: ['4o5', '3', '따풀', '초강다']
# 인식한 글자: ['Mo5', '드', '흔따물', '초강력']
# 인식한 글자: ['We5', '>', "'", '따물', '초강터']
# 인식한 글자: ['Mos', '{마물', '관']
# 인식한 글자: ['Wes', '마물', '{가9']
# 인식한 글자: ['Wes', '따풀', '초강리']
# 인식한 글자: ['Wo5', '따풀', '초강력']
# 인식한 글자: ['Wo5', '물', '초강리']
# 인식한 글자: ['Wes', '따물', '초강터']
# 인식한 글자: ['WoS', '따물', '조강리']
# 인식한 글자: ['We5', '따풀', '초강리']
# 인식한 글자: ['W5', '팔물', '총강터']
# 인식한 글자: ['Mes', '파물', '조강억']
# 인식한 글자: ['Me5', '팔물', '조강력']
# 인식한 글자: ['We5', '따물', '초강리']
# 인식한 글자: ['W5', '>', '따물', '초강력']
# 인식한 글자: ['Wo5', '>', "'파물", '조강다']
# 인식한 글자: ['Wo5', '8', '따물', '조강력']
# 인식한 글자: ['Mos', '8', '따물', '조강력']
# 인식한 글자: ['Wos', '3', '따물', '조강력']
# 인식한 글자: ['Mo5', '5', '따물', '조강력']
# 인식한 글자: ['Mo5', 's', '따물', '조강터']
# 인식한 글자: ['Mo5', 's', '따물', '조강력']
# 인식한 글자: ['Mo5', '5', '딱풀', '조강력']
# 인식한 글자: ['Mo5', '5', '따물', '조강력']
# 인식한 글자: ['Mo5', '5', '딱풀', '초강터']
# 인식한 글자: ['4o5', '9', '딱풀', '조강력']
# 인식한 글자: ['Mos', 'S', '딱물', '조강력']
# 인식한 글자: ['Mo5', '9', '딱물', '초강력']
# 인식한 글자: ['Mo5', '$', '딱물', '초강력']
# 인식한 글자: ['Mo5', '9', '딱물', '초강터']
# 인식한 글자: ['Mos', '$', '9', '딱풀', '초강력']
# 인식한 글자: ['Mo5', '9', '83', '딱풀', '초강력']
# 인식한 글자: ['N5', '드5', '8', '딱물', '조강터']
# 인식한 글자: ['Mo5', '들>', '93', '딱풀', '초강다']
# 인식한 글자: ['Mo5', '9', '83', '딱풀', '초강력']
# 인식한 글자: ['Mo5', '9', '9', '딱물', '초강터']
# 인식한 글자: ['Mo5', '9', '드3', '딱풀', '초강력']
# 인식한 글자: ['Mo5', '9', '드3', '딱물', '초강력']
# 인식한 글자: ['Mo5', '9', '드3', '딱물', '초강력']
# 인식한 글자: ['Mo5', '9', '93', '딱물', '초강력']
# 인식한 글자: ['Mo5', '9', '93', '딱풀', '초강력']
# 인식한 글자: ['Mo5', '9', '93', '딱풀', '초강력']
# 인식한 글자: ['Mo5', '9', '93', '딱풀', '초강력']
# 인식한 글자: ['Mo5', '9', '딱풀', '초강력']
# 인식한 글자: ['Mo5', '딱풀', '조강력']
# 인식한 글자: ['Mo5', '9', '딱물', '초강력']
# 인식한 글자: ['Mo5', '9', '딱물', '초강력']
# 인식한 글자: ['Mo5', '$', '93', '초강터', '딱물']
# 인식한 글자: ['Mo5', '9', '8', '초강터', '딱물']
# 인식한 글자: ['No5', '$', '8', '딱물', '초강력']
# 인식한 글자: ['No5', '9', '초강리', '딱풀']
# 인식한 글자: ['No5', '9', '93', "'따물", '초강터']
# 인식한 글자: ['Mo5', '$', '초강터', '막물']
# 인식한 글자: ['Mo5', '9', '막물', '초강다']
# 인식한 글자: ['Mo5', '9', "'따물", '초강리']
# 인식한 글자: ['Mo5', '9', '딱풀', '초강리']
# 인식한 글자: ['Mo5', '9', '딱풀', '초강다']
# 인식한 글자: ['Mo5', '9', '딱풀', '조강다']
# 인식한 글자: ['Mos', '9', "'따물", '초강어']
# 인식한 글자: ['Mo5', '$', "'따물", '초강이']
# 인식한 글자: ['Mo5', '95', '93', '초강다', '딱풀']
# 인식한 글자: ['Me5', '9', "'따물", '조강기']
# 인식한 글자: ['M5', '95', '따풀', '조강리']
# 인식한 글자: ['Mo5', '95', '드?', '따물', '초강다']
# 인식한 글자: ['M5', "'따물", '조강다']
# 인식한 글자: ['Mo5', '따물', '초강기']
# 인식한 글자: ['Mo5', '따물', '초강터']
# 인식한 글자: ['Mo5', '따물', '초강리']
# 인식한 글자: ['4o5', '따물', '초강리']
# 인식한 글자: ['Mo5', '초강되', '딱물']
# 인식한 글자: ['MS', '따물', '9', '초강적']
# 인식한 글자: ['Mo5', "'따물", '초강터']
# 인식한 글자: ['Mo5', '따물', '9', '초강리']
# 인식한 글자: ['Mo5', '딱물', '초강력']
# 인식한 글자: ['AS', '따물', '9', '초강리']
# 인식한 글자: ['MoS', '따물', '9', '초강리']
# 인식한 글자: ['MoS', '9', '초강력', '딱물']
# 인식한 글자: ['Mo5', "'따물", '초강적']
# 인식한 글자: ['M5', '초강터', '딱풀']
# 인식한 글자: ['Mo5', '초강터', '딱물']
# 인식한 글자: ['Mo5', '따물', '초강터']
# 인식한 글자: ['M5', "'따물", '초강적']
# 인식한 글자: ['MS', "'따물", '초강리']
# 인식한 글자: ['MS', "'따물", '조강리']
# 인식한 글자: ['MoS', '초강리', '딱물', '9']
# 인식한 글자: ['N:S', '딱물', '초강다']
# 인식한 글자: ['AoS', '딱물', '조강']
# 인식한 글자: ['Mo5', "'따물", '조강리']
# 인식한 글자: ['Mo5', '딱물', '초강리']
# 인식한 글자: ['No5', '딱물', '초강리']
# 인식한 글자: ['Ao5', '대사무시', '딱물', '초강다']
# 인식한 글자: ['No5', '딱물']
# 인식한 글자: ['Ao5', '9', '93', '딱물', '초강이']
# 인식한 글자: ['NS', '드3', '딱물']
# 인식한 글자: ['AoS', '93', '딱물']
# 인식한 글자: ['AoS', '딱물', '초강리']
# 인식한 글자: ['4o5', '$', '초강리', '딱물']
# 인식한 글자: ['No5', '딱물', '초강리']
# 인식한 글자: ['NMoS', '국강', '딱물']
# 인식한 글자: ['Ao5', '딱물', '조강리']
# 인식한 글자: ['Aos', '93', '따물', '초강']
# 인식한 글자: ['AoS', '따물', '초강리']
# 인식한 글자: ['AoS', '9', "'따물", '초강리']
# 인식한 글자: ['AoS', '9', "'따물", '초강리']
# 인식한 글자: ["7' 5 s", 'AoS', '9', "'따물", '초강리']
# 인식한 글자: ['KCs', 'AMoS', '9', "'딱물", '초강리']
# 인식한 글자: ['AMoS', '9', "'따물", '조강리']
# 인식한 글자: ['AoS', '9', '93', '딱물', '초강리']
# 인식한 글자: ['Ae5', '9', '93', '딱물']
# 인식한 글자: ['Ae5', '9', '93', '딱풀', '6강다']
# 인식한 글자: ['AoS', '딱풀', '초강리']
# 인식한 글자: ['4eo5', '93', '드?', '딱물', '초강리']
# 인식한 글자: ['AeS', '9', 'S3', '딱물', '조강다']
# 인식한 글자: ['AoS', '93', '딱물', '조강다']
# 인식한 글자: ['AMoS', '9', '드3', '따물', '조강다']
# 인식한 글자: ['AeS', '<3', '딱물', '초강리']
# 인식한 글자: ['Aos', '9', '딱물']
# 인식한 글자: ['AoS', '따물']
# 인식한 글자: ['AeS', '딱물']
# 인식한 글자: ['AoS', '따물', '초강다']
# 인식한 글자: ['Aes', '딱물', '초강다']
# 인식한 글자: ['Aos', "'", '딱물', '초강다']
# 인식한 글자: ['7 -다', 'Aos', '따물', '드?']
# 인식한 글자: ['퍽다 E4', 'AeS', '그', '93', '딱물']
# 인식한 글자: ['AoS', '>', '딱물']
# 인식한 글자: ['Aos', '93', '딱물', '조강리']
# 인식한 글자: ['Aes', '83', '딱물']
# 인식한 글자: ['Aos', '9', '딱물', '초강']
# 인식한 글자: ['Aes', '9', '93', '따물', '초강리']
# 인식한 글자: ['Ao5', '>', '83', '딱물']
# 인식한 글자: ['AeS', '도3', '>', '딱물', '조강다']
# 인식한 글자: ['NoS', '$', '93', '93', '조강', '딱물']
# 인식한 글자: ['AoS', '93', '93', '93', '딱물']
# 인식한 글자: ['AoS', '93', '딱물', '초강다']
# 인식한 글자: ['Aos', 'S3', '딱물', '초강리']
# 인식한 글자: ['Ao5', '93', '초강리', '딱물']
# 인식한 글자: ['Nos', '9', '우', '딱물']
# 인식한 글자: ['Ae5', '오', '딱물']
# 인식한 글자: ['AoS', '9', '따물', '초강다']
# 인식한 글자: ['AoS', '<', '딱물']
# 인식한 글자: ['AoS', 'S3', '딱물']
# 인식한 글자: ['Ao5', '따물']
# 인식한 글자: ['AoS', '93', '93', '따물', '초강디']
# 인식한 글자: ['Aos', '9', '93', '딱물', '초강디']
# 인식한 글자: ['AoS', '초강터', '딱물']
# 인식한 글자: ['Ao5', '9', '9', '딱물', '초강다']
# 인식한 글자: ['AoS', '93', '초강력', '딱풀']
# 인식한 글자: ['Ao5', '93', '따물']
# 인식한 글자: ['Ao5', '9', '9', '93', '초강리', '딱물']
# 인식한 글자: ['AoS', '9', '9', '93', '따물', '초강터']
# 인식한 글자: ['NYos', '9', '드=', '93', '따물', '초강리']
# 인식한 글자: ['AMo', '93', '따물']
# 인식한 글자: ['Ae5', '<', '딱물']
# 인식한 글자: ['Ae5', '93', '딱물']
# 인식한 글자: ['Ao5', '3', '딱물']
# 인식한 글자: ['Ao5', '93', '딱물']
# 인식한 글자: ['Ao5', '93', '9', '따물']
# 인식한 글자: ['AoS', '9', '93', '따물']
# 인식한 글자: ['AMes', '93', '딱물']
# 인식한 글자: ['AoS', 'S', '95', '딱물']
# 인식한 글자: ['Ao5', ':3', '딱물']
# 인식한 글자: ['AoS', '9', '딱물', '초강대']
# 인식한 글자: ['Ao5', '93', '따물', '초강다']
# 인식한 글자: ['AoS', '93', '딱물', '초강다']
# 인식한 글자: ['Ao5', '95', '도3', '따물', '초강터']
# 인식한 글자: ['Ao5', '93', '초강리', '딱물']
# 인식한 글자: ['AoS', '9', '93', '따물', '초강리']
# 인식한 글자: ['Ao5', '9', '따물', '초강리']
# 인식한 글자: ['Aos', '9', '따물', '초강리']
# 인식한 글자: ['Aos', '93', '따물', '초강리']
# 인식한 글자: ['AoS', '9', '드3', '따물', '초강리']
# 인식한 글자: ['Aos', '9', 'S3', '초강리', '딱물']
# 인식한 글자: ['Aos', '9', 'S3', '딱물', '초강리']
# 인식한 글자: ['AoS', '도3', '9', '초강터', '딱물']
# 인식한 글자: ['Ae5', '93', "'따물"]
# 인식한 글자: ['AoS', '93', "'따물", '초강']
# 인식한 글자: ['AeS', '93', '딱물', '조강리']
# 인식한 글자: ['AoS', '드3', '딱풀', '초강터']
# 인식한 글자: ['AoS', '93', '따물', '초강']
# 인식한 글자: ['AoS', '9', '93', '딱물', '초강리']
# 인식한 글자: ['Ae5', '93', '93', '초강리', '딱물']
# 인식한 글자: ['AoS', '9', '93', '딱물', '조강다']
# 인식한 글자: ['4e5', '93', '93', '초강터', '딱풀']
# 인식한 글자: ['AoS', '9', '93', '딱풀', '초강리']
# 인식한 글자: ['AoS', '93', '9', '초강리', '딱풀']
# 인식한 글자: ['AoS', '93', '딱물', '조강리']
# 인식한 글자: ['Ao5', '93', '93', '딱풀']
# 인식한 글자: ['4o5', '93', '딱풀']
# 인식한 글자: ['AoS', '93', '딱풀']
# 인식한 글자: ['MoS', '드', '딱풀', '초강리']
# 인식한 글자: ['AoS', '93', '딱풀', '초강']
# 인식한 글자: ['MoS', '93', '딱풀', '초강다']
# 인식한 글자: ['4o5', '9', '93', '따물', '초강리']
# 인식한 글자: ['4o5', '95', '93', '딱풀', '초강리']
# 인식한 글자: ['MoS', '9', '93', '딱풀', '초강리']
# 인식한 글자: ['MoS', '9', '93', '딱풀', '초강리']
# 인식한 글자: ['Mo5', '9', '따물', '초강터']
# 인식한 글자: ['AeS', '초강다', '딱풀']
# 인식한 글자: ['AeS', '따물', '초강력']
# 인식한 글자: ['Ao5', '9', '초강터', '딱풀']
# 인식한 글자: ['AeS', '9', '따물', '초강력']
# 인식한 글자: ['Ao', 's', '93', '딱물', '초강기']
# 인식한 글자: ['Me5', '9', '따풀', '초강리']
# 인식한 글자: ['Ao5', '$', '초강다', '딱풀']
# 인식한 글자: ['Mo5', '$', '딱풀', '어강']
# 인식한 글자: ['MoS', '$', '드3', '딱풀', '초강리']
# 인식한 글자: ['MoS', '95', '딱물', '조강이']
# 인식한 글자: ['4o5', '딱풀', '초강리']
# 인식한 글자: ['Mo5', '9', '93', '따물', '조강리']
# 인식한 글자: ['4o5', '$', '93', '딱풀']
# 인식한 글자: ['4o5', '따풀', '조강']
# 인식한 글자: ['MoS', '따풀', '초강']
# 인식한 글자: ['Mo5', '따풀', '초강대']
# 인식한 글자: ['MeS', '$', '따풀', '초강다']
# 인식한 글자: ['MeS', '마물', '초감기']
# 인식한 글자: ['MeS', '$', '초강리', '따물']
# 인식한 글자: ['Me5', '따물', '초강리']
# 인식한 글자: ['Mo5', '따물', '초강터']
# 인식한 글자: ['MoS', '초강-', '따따물']
# 인식한 글자: ['WeS', '따따물']
# 인식한 글자: ['MoS', '따마물', '조강리']
# 인식한 글자: ['Mes', '9', '흔따물']
# 인식한 글자: ['MoS', '9', '따따풀']
# 인식한 글자: ['MeS', '9', '@따물', '초강리']
# 인식한 글자: ['4e5', '중따물', '초강리']
# 인식한 글자: ['Wes', '중막풀', '초강리']
# 인식한 글자: ['Mes', '따물', '초강리']
# 인식한 글자: ['Mes', '9', '십싸풀', '조강다']
# 인식한 글자: ['MoS', '9', '@따풀', '초강리']
# 인식한 글자: ['MoS', '$', '따물']
# 인식한 글자: ['4eS', '9', '따물']
# 인식한 글자: ['MoS', '십물', '조강리']
# 인식한 글자: ['4eS', '9', '따풀', '*강리']
# 인식한 글자: ['WeS', '9', '따물']
# 인식한 글자: ['Me5', '마풀', '조강리']
# 인식한 글자: ['MeS', 's', '따물']
# 인식한 글자: ['Mo5', '9', '초강적', '막풀']
# 인식한 글자: ['MoS', '따물', '초강리']
# 인식한 글자: ['Me5', '9', '따물', '조강리']
# 인식한 글자: ['MeS', '9', '따풀', '초강리']
# 인식한 글자: ['Mo5', '9', '따물', '초강리']
# 인식한 글자: ['Mo5', '9', '따물', '초강터']
# 인식한 글자: ['Mo5', 's', '초강적', '마물']
# 인식한 글자: ['Mo5', '9', '딱풀', '조강업']
# 인식한 글자: ['Wo5', '9', '따풀', '조강력']
# 인식한 글자: ['4o5', '9', '딱풀', '초강여']
# 인식한 글자: ['4o5', '초강력', '딱물']
# 인식한 글자: ['4o5', '딱물', '조강력']
# 인식한 글자: ['4o5', '딱물', '조강억']
# 인식한 글자: ['AoS', '9', '초강력', '딱풀']
# 인식한 글자: ['MoS', '따물', '초강리']
# 인식한 글자: ['AoS', '딱물', '초강리']
# 인식한 글자: ['Ao5', '9', "'따물", '초강리']
# 인식한 글자: ['Mo5', '딱물', '초강리']
# 인식한 글자: ['Mo5', '딱풀', '초강리']
# 인식한 글자: ['Mo5', '9', '딱풀', '초강리']
# 인식한 글자: ['AoS', '딱풀', '초강리']
# 인식한 글자: ['4o5', '딱물', '초강리']
# 인식한 글자: ['93', 'Mes', '딱물', '초강리']
# 인식한 글자: ['Mo5', '93', '따물', '초강리']
# 인식한 글자: ['Mo5', '초강력', '딱풀']
# 인식한 글자: ['Ao5', '93', '딱물', '조강리']
# 인식한 글자: ['AoS', '93', '딱물', '조강리']
# 인식한 글자: ['AoS', '93', "'딱물", '초강력']
# 인식한 글자: ['Ao5', '9', '93', '딱물', '조강억']
# 인식한 글자: ['4o5', '93', '딱물', '초강력']
# 인식한 글자: ['Aos', 'S3', '딱물', '초강력']
# 인식한 글자: ['MoS', '93', '딱물', '초강리']
# 인식한 글자: ['AoS', '93', '딱물', '초강력']
# 인식한 글자: ['Ao5', '딱물', '초강리']
# 인식한 글자: ['AoS', '딱물', '조강리']
# 인식한 글자: ['Aos', '9', '딱물', '조강력']
# 인식한 글자: ['4o5', '9', "'따물", '조강력']
# 인식한 글자: ['AoS', '딱물', '초강리']
# 인식한 글자: ['No5', '93', '딱물', '조강']
# 인식한 글자: ['Ao5', '딱물', '조강억']
# 인식한 글자: ['AoS', '딱풀']
# 인식한 글자: ['AoS', '', '딱물', '조강력']
# 인식한 글자: ['AYoS', '>', '딱풀', '초강터']
# 인식한 글자: ['NoS', '>', '9', '93', '딱물']
# 인식한 글자: ['4oS', '>', '93', '딱물']
# 인식한 글자: ['AoS', '좀', '따물']
# 인식한 글자: ['Ao5', '좀', '9', '딱물', '93']
# 인식한 글자: ['4o5', '드', '9', '93', '딱물']
# 인식한 글자: ['Ao5', '올', '93', '딱물', '소강력']
# 인식한 글자: ['No5', '목', '딱물', '조강력']
# 인식한 글자: ['Ao}', '$', '93', '딱물']
# 인식한 글자: ['AeS', '우', '93', '따물', '초강리']
# 인식한 글자: ['Ao5', '93', '딱물']
# 인식한 글자: ['Aos', '드', '9', 'S3', '딱물', '초강력']
# 인식한 글자: ['Ao5', '9', '9', '83', '딱물', '강력']
# 인식한 글자: ['Aos', '9', 'S3', '딱물', '초강리']
# 인식한 글자: ['Ao5', '$', '9', '따물', '소강:']
# 인식한 글자: ['No5', 's', '9>', '딱물', '초강력']
# 인식한 글자: ['9', 'Aos', '딱물']
# 인식한 글자: ['AoJ', '딱물']
# 인식한 글자: ['Ae', '드', '9', 'S3', '딱물']
# 인식한 글자: ['Aos', 's', '9', '딱물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['4o;', '들', '93', '딱물']
# 인식한 글자: ['Aoj', '$', '도3', '딱물']
# 인식한 글자: ['$', '3', 'Aos', '딱물']
# 인식한 글자: ['드', 'Aos', '딱물']
# 인식한 글자: ['드', 'AMos', '딱물']
# 인식한 글자: ['3', 'AMos', '딱물']
# 인식한 글자: ['AoJ', '9', '딱물']
# 인식한 글자: ['AoJ', '딱물']
# 인식한 글자: ['Aos', '$', '93', '딱물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['따물', 'Aos']
# 인식한 글자: ['딱물', 'Aos']
# 인식한 글자: ['9', '93', '딱물', 'Aos']
# 인식한 글자: ['AoJ', '9', '딱물', '9']
# 인식한 글자: ['Aos', '9', '93', '딱물']
# 인식한 글자: ['Aos', '9', '들3', '딱물']
# 인식한 글자: ['Aoy', '9', '딱물']
# 인식한 글자: ['Noy', '따물', '조강다']
# 인식한 글자: ['Aey', '따물']
# 인식한 글자: ['Aoy', '9', '따물']
# 인식한 글자: ['9', '93', '3', 'Aos', '따물', '초강대']
# 인식한 글자: ['Ao;', '9', '딱물', '초강대']
# 인식한 글자: ['4o5', '9', '따물', '초강다']
# 인식한 글자: ['NVoy', '따풀', '초강대']
# 인식한 글자: ['4e5', '9', '8', '9', '따물', '초강이']
# 인식한 글자: ['Aoy', '95', '9', '따풀', '귀강다']
# 인식한 글자: ['Ao5', '오3', '9', '딱물', '조강터']
# 인식한 글자: ['9', '9', '93', '83', 'AMoS', '딱물', '초강디']
# 인식한 글자: ['4Yo5', '9', '9', '93', '딱물', '초강리']
# 인식한 글자: ['4Yoy', '9', '9', '93', '딱물']
# 인식한 글자: ['AoS', '9', '93', '93', '딱물']
# 인식한 글자: ['9', '9', '9', 'AoS', '딱물', '조강리']
# 인식한 글자: ['AVo5', '9', '9', '93', '딱물']
# 인식한 글자: ['Ao5', '9', '83', '딱물']
# 인식한 글자: ['$', '83', 'AMoS', '딱풀', '조랑다']
# 인식한 글자: ['9', '9', 'S3', 'AMoy', '딱물', '초강다']
# 인식한 글자: ['9', '9', '9', 'AMoS', '딱물', '조강']
# 인식한 글자: ['9', '9', '83', 'AMos', '딱물', '조망']
# 인식한 글자: ['9', '93', 'AMoS', '딱물', '조강리']
# 인식한 글자: ['9', '93', 'AMoy', '93', '딱물', '초강터']
# 인식한 글자: ['4oy', '9', '93', '9', '딱물']
# 인식한 글자: ['9', '93', '93', '93', 'AMos', '딱물']
# 인식한 글자: ['47', '9', '9', '93', '딱물']
# 인식한 글자: ['4aj', '83', '딱물', '조강:']
# 인식한 글자: ['4o', '8', '딱물', '3']
# 인식한 글자: ['4a', '9', '$', '딱물', '129']
# 인식한 글자: ['48', '9', '$', '9', '$', '딱물']
# 인식한 글자: ['4763', '9', '8', '초장', '딱물']
# 인식한 글자: ['4o5', '95', '9', '83', '딱물']
# 인식한 글자: ['4oy', '오', '9', '93', '9', '딱물', '숫장다']
# 인식한 글자: ['465', 's', '9', '9', '$', '딱풀', '조강다']
# 인식한 글자: ['46s', '=', '9', '9', '83', '딱물', '초선여']
# 인식한 글자: ['48y', '극', '9', '93', '9', '딱물', '초장']
# 인식한 글자: ['4Vs', '9', '도3', '93', '딱물']
# 인식한 글자: ['4ay', '$', '도3', '83', '딱풀']
# 인식한 글자: ['483', '$', '73', '93', '딱풀']
# 인식한 글자: ['483', '9', '93', '93', '딱풀']
# 인식한 글자: ['48s', '9', '93', '$', '딱물', '*39']
# 인식한 글자: ['485', '93', '8', '딱물', '*39']
# 인식한 글자: ['465', '9', '93', '딱풀']
# 인식한 글자: ['465', '93', "'따물", '귀리여']
# 인식한 글자: ['485', '8', '딱물', '*2다']
# 인식한 글자: ['46S', '9', '93', '93', '_파물']
# 인식한 글자: ['4S', 'S', '3', '93', '딱물']
# 인식한 글자: ['43', '$', '9', '9', "'따물", '가리']
# 인식한 글자: ['4e5', '9', '9', '따풀', '179']
# 인식한 글자: ['465', 'S', '9', '9', '따풀', '*889']
# 인식한 글자: ['465', 'S', '9', '따물']
# 인식한 글자: ['4)', '5', '73', '*장', '따물']
# 인식한 글자: ['46S', '5', '9', '따풀', '*8']
# 인식한 글자: ['46S', '>', '9', ')강력', '파풀']
# 인식한 글자: ['4os', '>', '93', ')강력', '파풀']
# 인식한 글자: ['MoS', '5', '93', '파풀', '*강9']
# 인식한 글자: ['47o5', '5', '9', "'파풀", '선강리']
# 인식한 글자: ['Wo5', '>', '9', "'파풀", '처강9']
# 인식한 글자: ['4o5', '93', "'막풀", '총강리']
# 인식한 글자: ['4e5', '3', '93', "'막풀", '초강리']
# 인식한 글자: ['Mo5', '5', '9', "'풀", '총강리기']
# 인식한 글자: ['Mos', '5', '53', "'파풀", '조강대']
# 인식한 글자: ['4o5', '*', '파풀']
# 인식한 글자: ['Mo5', '9', '파물', '차강대']
# 인식한 글자: ['Wo5', '9', '파물', '거강대']
# 인식한 글자: ['We5', '9', '따풀', '빨강다']
# 인식한 글자: ['M5', '9', '따풀', '초강대']
# 인식한 글자: ['Wos', '9', '따물', '고강이']
# 인식한 글자: ['WeS', '마물', '(V이']
# 인식한 글자: ['We5', '마물', '처강기']
# 인식한 글자: ['Wo5', '파물', '총강리']
# 인식한 글자: ['MWe5', '파풀', '조강다']
# 인식한 글자: ['We5', '따물', '초강리']
# 인식한 글자: ['W5', '따풀', '초강리']
# 인식한 글자: ['Wo5', '따풀', '초강적']
# 인식한 글자: ['4s', '트라물', '*선적']
# 인식한 글자: ['45', '트라물', '3']
# 인식한 글자: ['43', '3', '트라물', '2 ']
# 인식한 글자: ['43', 's', '9', '93', '퍽물', '표3 2']
# 인식한 글자: ['4s', '$', '퍽풀', '*3여']
# 인식한 글자: ['4o5', 'S', '딱풀', '조강력']
# 인식한 글자: ['드', 'Mos', '딱풀', '조강리']
# 인식한 글자: ['4', '9', '드)', '딱물', '조강다']
# 인식한 글자: ['4o5', '우', '93', '따물', '초강대']
# 인식한 글자: ["'따물", 'MoS', '초강다']
# 인식한 글자: ['No5', '93', '딱물', '초강다']
# 인식한 글자: ['9', '9', '93', 'Mos', '딱물', '초강리']
# 인식한 글자: ['NS', '$', '8', '딱물', '조강리']
# 인식한 글자: ['M5', '$', '8', '딱물', '조강어']
# 인식한 글자: ['N', '8', '딱물', '총강어']
# 인식한 글자: ['No5', '$', '93', '딱물', '총강히']
# 인식한 글자: ['Nos', 'S', '93', '조강', '딱물']
# 인식한 글자: ['N5', '9', '93', '93', '딱물']
# 인식한 글자: ['95', 'Mes', '딱풀', '초강터']
# 인식한 글자: ['No', '딱풀', '초강다']
# 인식한 글자: ['No5', '딱물', '초강리']
# 인식한 글자: ['N', '$', '딱풀', '조강이']
# 인식한 글자: ['Ns', 's', '딱풀', '초강리']
# 인식한 글자: ['NS', 'S', '딱풀', '초강리']
# 인식한 글자: ['NS', '9', '딱풀', '초강리']
# 인식한 글자: ['N', '$', '따물', '초강']
# 인식한 글자: ['No5', 'S', '9', '딱풀', '초강']
# 인식한 글자: ['N:S', 'S', '93', '93', '딱풀']
# 인식한 글자: ['N5', '$', '9', '딱물', '0강히']
# 인식한 글자: ['45', '$', '93', '93', '딱풀', '조강터']
# 인식한 글자: ['M5', '$', "'", '딱풀', '초강터']
# 인식한 글자: ['4o5', '9', '93', '딱물', '초강다']
# 인식한 글자: ['N', '93', '93', '딱물', '초강리']
# 인식한 글자: ['A5', '딱물', '초강리']
# 인식한 글자: ['NS', '9', '딱풀', '초강리']
# 인식한 글자: ['M5', '딱물', '초강리']
# 인식한 글자: ['NS', '딱물', '초강다']
# 인식한 글자: ['N5', '딱풀', '초강터']
# 인식한 글자: ['M5', '초강터', '딱물']
# 인식한 글자: ['M5', '초강리', '딱물']
# 인식한 글자: ['MS', '딱풀', '초강리']
# 인식한 글자: ['Ns', '$', '드?', '딱물', '초강리']
# 인식한 글자: ['Ms', '드3', '딱물', '초강리']
# 인식한 글자: ['$', 'Mes', '딱풀', '초강리']
# 인식한 글자: ['NS', '9', "'딱물", '초강리']
# 인식한 글자: ['Mo5', '9', '딱물', '조강다']
# 인식한 글자: ['NS', '$', '딱풀', '초강리']
# 인식한 글자: ['N5', '9', '초강터', '딱풀']
# 인식한 글자: ['No5', '초강리', '딱풀']
# 인식한 글자: ['NS', '딱물', '초강리']
# 인식한 글자: ['N5', '딱물', '초강리']
# 인식한 글자: ['45', '우', '딱풀', '초강리']
# 인식한 글자: ['Ns', '$', '딱물', '조강다']
# 인식한 글자: ['NW5', '9', '93', '딱풀', '초강기']
# 인식한 글자: ['9', '초강터', 'MeS', '딱풀']
# 인식한 글자: ['NS', '93', '딱풀', '초강리']
# 인식한 글자: ['N5', '93', '딱풀', '초강리']
# 인식한 글자: ['93', 'MoS', '딱물', '초강터']
# 인식한 글자: ['45', '$', '초강적', '딱물']
# 인식한 글자: ['45', 's', '딱물', '조강리']
# 인식한 글자: ['Mo5', '9', '딱풀', '초강리']
# 인식한 글자: ['M5', '$', '따물', '초강리']
# 인식한 글자: ['M5', '9', '따물', '초강리']
# 인식한 글자: ['NS', '9', '따물', '조강리']
# 인식한 글자: ['M5', '딱풀', '초강리']
# 인식한 글자: ['Mo5', '9', '딱물', '초강리']
# 인식한 글자: ['MS', '9', '딱물', '초강리']
# 인식한 글자: ['M5', '$', '93', '93', '딱풀', '초강리']
# 인식한 글자: ['$', 'S3', 'MeS', '딱풀', '초강적']
# 인식한 글자: ['N5', '$', 'S', '딱풀', '초강리']
# 인식한 글자: ['NS', '9', '딱풀', '초강리']
# 인식한 글자: ['MeS', '딱풀', '초강리']
# 인식한 글자: ['NS', '따물', '초강리']
# 인식한 글자: ['N5', '$', '딱물', '초강리']
# 인식한 글자: ['N', 's', '초강적', '따물']
# 인식한 글자: ['N', '$', '따물', '조강다']
# 인식한 글자: ['No', '9', '딱풀', '조강리']
# 인식한 글자: ['NoS', '9', '딱물', '초강리']
# 인식한 글자: ['N', '$', '93', '딱물', '초강터']
# 인식한 글자: ['$', '93', '초강리', 'MoS', '딱물']
# 인식한 글자: ['N', '$', '9', '따물', '조강력']
# 인식한 글자: ['AVS', '딱풀', '초강리']
# 인식한 글자: ['N:', '$', '딱풀', '초강리']
# 인식한 글자: ['N:', '$', '따풀', '초강리']
# 인식한 글자: ['N', '$', '딱풀', '초강기']
# 인식한 글자: ['Ne', '$', '딱물', '초강다']
# 인식한 글자: ['N5', 's', '조강터', '딱물']
# 인식한 글자: ['NS', '딱물', '초강리']
# 인식한 글자: ['NVo5', '9', '막풀', '초강리']
# 인식한 글자: ['No5', '$', '따물', '초강리']
# 인식한 글자: ['NWo5', '딱물', '초강리']
# 인식한 글자: ['No5', '9', "'", '초강터', '딱풀']
# 비디오 종료
# Mean score of BLEU: 0.18304431599229287, Total Frame: 519

# %% [markdown]
# ## 실험결과 정리
#
# |품목 이름|평균 BLEU 스코어|프레임 수|
# |---|---|---|
# |Cetaphil|0.295|325|
# |만능크리너|0.88|443|
# |정관장|0.48|434|
# |딱풀|0.18|437|
