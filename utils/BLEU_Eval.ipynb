# %% [markdown]
# # 문장 평가
# - [잘 설명해준 사이트](https://jrc-park.tistory.com/273)
# - 생성된 문장을 평가하는 방식은 크게 2가지 (Reference가 Ground truth로 보면 되는 듯)
#   1. Rouge: Reference 문장의 단어가 Generated 문장에 포함되는 정도
#      - Text Summarization
#   2. **BLEU**: Generated 문장의 단어가 Reference Sentence에 포함되는 정도
#      - Machine Translation

# %% [markdown]
# ## 코드 예시

# %%
from nltk.translate.bleu_score import sentence_bleu
reference = [["this", "is", "the", "sample"]]
candidate = ['this', "is", "the", "sample"]
score1 = sentence_bleu(reference, candidate, weights=(1, 0, 0, 0)) # 1.0

score1
# Out:
# 1.0

# %% [markdown]
# # N-gram
# - 위 sentence_bleu 함수의 weights 인자에 들어가는것이 N-gram 인자이며 (1, 0, 0, 0)은 1-gram token들로만 평가를 진행한다는 의미
#   - 1-gram
#     - this, is, the, sample
#   - 2-gram
#     - this is, is the, the sample
#   - 3-gram
#     - this is the, is the sample
#   - 4-gram
#     - this is the sample
# - gram 수가 올라갈수록 **순서를 정확히 고려**해야 하므로 높은 점수를 받기가 쉽지 않아짐

# %%
import warnings
warnings.filterwarnings('ignore')

reference = [["나는", "너를", "사랑해", "정말로"]]
candidate = ["나는", "사랑해", "정말로", "너를"]
candidate_v2 = ["나는", "사랑해", "너를", "정말로"]
gram1 = sentence_bleu(reference, candidate, weights=(1, 0, 0, 0))
gram2 = sentence_bleu(reference, candidate, weights=(0, 1, 0, 0))
gram_v2 = sentence_bleu(reference, candidate_v2, weights=(0, 1, 0, 0)) # 1.0

print(f'1-gram score: {gram1}, 2-gram score: {gram2}, 2-gram_v2 score: {gram_v2}')
# Out:
# 1-gram score: 1.0, 2-gram score: 0.3333333333333333, 2-gram_v2 score: 2.2250738585072626e-308

# %% [markdown]
# - 2-gram의 경우 "사랑해", "정말로" 를 통해 2-gram 에 포함되어 있는 문장을 맞췄지만 2-gram_v2의 경우에는 그렇지 못해서 0 값(표기상으론 아주 작은값)을 받은 걸 알 수 있음

# %% [markdown]
# # Easy-OCR BLEU 기반 성능 테스트
# - 실시간으로 이미지를 계속 읽어와서 테스트를 진행하고자 한다

# %% [markdown]
# ## 영상 저장 코드

# %%
import datetime
import cv2

device_id = 1

capture = cv2.VideoCapture(device_id)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
record = False

while True:
    if(capture.get(cv2.CAP_PROP_POS_FRAMES) == capture.get(cv2.CAP_PROP_FRAME_COUNT)):
        capture.open(device_id)

    ret, frame = capture.read()
    cv2.imshow("VideoFrame", frame)

    now = datetime.datetime.now().strftime("%d_%H-%M-%S")
    key = cv2.waitKey(33)

    if key == 27:       # ESC
        break
    elif key == 26:     # Ctrl - Z
        print("캡쳐")
        cv2.imwrite("D:/" + str(now) + ".png", frame)
    elif key == 24:     # Ctrl - X
        print("녹화 시작")
        record = True
        video = cv2.VideoWriter("D:/" + str(now) + ".avi", fourcc, 20.0, (frame.shape[1], frame.shape[0]))
    elif key == 3:      # Ctrl - C
        print("녹화 중지")
        record = False
        video.release()
        
    if record == True:
        video.write(frame)

capture.release()
cv2.destroyAllWindows()
# Out:
# 녹화 시작

# %%
import easyocr
import cv2
import numpy as np
import warnings
import time
warnings.filterwarnings('ignore')
from nltk.translate.bleu_score import sentence_bleu

def BLEU_mean(source:str, ref:list):
    mean_val = 0
    count = 0
    # cam = cv2.VideoCapture(0)     # if you want to use webcam
    cam = cv2.VideoCapture(source)        # if you want to read video file
    reader = easyocr.Reader(['ko', 'en'], gpu=True)

    reference = [ref]

    while True:
        check,frame = cam.read()
        if not check:
            print("비디오 종료")
            break
        
        count += 1

        cv2.imshow('video', frame)
        result = reader.readtext(frame)
        # candidate = []

        if len(result) != 0:        # 뭔가 잡았다면
            text = []
            for obj in result:
                # bbox = obj[0]
                text.append(obj[1])
                # confidence = obj[2]
            bleu_score = sentence_bleu(reference, text, weights=(1, 0, 0, 0)) # 1.0
            
            if bleu_score != 0.0:       # 많은 예측값들 중 정답 단어를 예측한게 있다면
                mean_val += 1.0
            
            else:
                pass

            print(f"인식한 글자: {text}")
            
        key = cv2.waitKey(1)
        if key == 27:
            break

    cam.release()
    cv2.destroyAllWindows
    return mean_val / count, count

source = 'C:/Users/hojun_window/Desktop/홍삼정환_편집본.mp4'
ref = ['정관장']
val, frames = BLEU_mean(source, ref)
print(f"Mean score of BLEU: {val}, Total Frame: {frames}")
# Out:
# 인식한 글자: ['홍신정토', 'I']
# 인식한 글자: ['VII V', '농사정만', "'"]
# 인식한 글자: ['홍심정환']
# 인식한 글자: ['홍심정환', '<', 'WVW', 'I']
# 인식한 글자: ['>관냥', '홍심정환', '{:{', 'Ma', 'dw', '9', "'oxos"]
# 인식한 글자: ['>관 %', 'N_', '홍심정환', "'stw", "':", 'ms', 'Ow', 'I']
# 인식한 글자: ['정관강', '홍상정환', 'wis', "'X", 'MT', 'd', '']
# 인식한 글자: ['정관장', '홍심정환', 'Ddoa', 'MS', 'SNI', '{4D']
# 인식한 글자: ['정관장', '홍상정환', 'v54833', 'M3i', '스O가다다', '4']
# 인식한 글자: ['정관장', '홍상정환', "{'", 'mO3a', 'Mi', '3N9', '45', ')']
# 인식한 글자: ['0', '정관장', '홍상정환', 'S', 'm니 3', 'MS', '적', '4']
# 인식한 글자: ['정관장', '홍심정환', 'm3', 'MO', 'wI', '~5']
# 인식한 글자: ['0', '정관장', '홍상정환', '@', 'm  3a', 'MS', 'F다', "'1c5"]
# 인식한 글자: ['홍심정환', 'C{', '또운 33', 'B', '14', 'N']
# 인식한 글자: ['홍상정문', '도문 요', '선- 우', 'NS']
# 인식한 글자: ['흥정든', 'o', '그', '4']
# 인식한 글자: ['홍상동', '2']
# 인식한 글자: ['흥임종', '24']
# 인식한 글자: ['홍4동', '21O)']
# 인식한 글자: ['6', '공', '6H)']
# 인식한 글자: ['흥4동', '21O)']
# 인식한 글자: ['홍상정문', 'ZcNO)']
# 인식한 글자: ["'스", '홍상정판', '396', '27', ' /3', 'eNOS']
# 인식한 글자: ["'크", '홍상정판', 'cNOS']
# 인식한 글자: ['경관강', '홍심정환', '2', '7', '19  33', '  ', 'KNOO)']
# 인식한 글자: ['정관장', '홍심정환', '?', '593 9- ', 'AeNOS']
# 인식한 글자: ['6', '정관장', '홍심정환', '흑m', '하이 "', '2?', '593x9 X', 'KNOS']
# 인식한 글자: ['6', '정관장', '홍심정환', 'G', '흑', " - '초'", '여e', '~S  ?X', 'KeNOS']
# 인식한 글자: ['6', '정관장', '홍심정환', "'", '', '내', 'e>', 'w - 5', 'KeNCS']
# 인식한 글자: ['6', '정관장', '홍심정환', '', '하7', '2>', 'yaw  3 n:', '수eNOS']
# 인식한 글자: ['6', '정관장', '홍심정환', 'wm', '벌', '-', '5C3>', 'KeNOS']
# 인식한 글자: ['6', '정관장', '홍심정환', '제', '도?', '593 99)', ' ', 'KeNOS']
# 인식한 글자: ['6', '정관장', '홍심정환', '8', "'", ':?', 'aw  S s>', 'KeNOS)']
# 인식한 글자: ['6', '정관장', '홍심정환', 'R', '53?', '고w S  ;', '', 'KeNOS']
# 인식한 글자: ['6', '정관장', '홍심정환', 'N', 'S:', 's요요드S', 'KeNCS']
# 인식한 글자: ['6', '정관장', '홍심정환', 'F', '어', "'??", "9소5 '스 T", 'KeNOS']
# 인식한 글자: ['6', '정관장', '홍상정환', "'", '현)', '<333', '959드 T', 'KeNCS']
# 인식한 글자: ['6', '정관장', '홍심정환', '', "'", '<33', 'ssows s X', 'KeNOS']
# 인식한 글자: ['6', '정관장', '홍심정환', '', '9333', 'sa s  sXn', ' ', 'kUNCa']
# 인식한 글자: ['6', '정관장', '홍심정환', 'US', '학해', '233 >', 'T  T<7', 'KeNOS']
# 인식한 글자: ['6', 'V', '정관장', '홍심정환', '3 3u   ', 'KS', 'a', '일9>', 'KeNOS']
# 인식한 글자: ['6', '정관장', '홍심정환', "'39sx", 'TS', 'a', '일9>', 'KcNCD']
# 인식한 글자: ['6', '정관장', '홍심정환', "'", 'Ma', '하nT', '오3 >', '"sows s 담', 'KeNOS']
# 인식한 글자: ['6', '정관장', '홍심정환', '39   3', 'Ta"', 'Bb"', '{', 'KeNCS']
# 인식한 글자: ['6', '정관장', '홍심정환', '또 3u 3 ', 'OI', 'vm', 'keNCS']
# 인식한 글자: ['6', '정관장', '홍심정환', '모3"  스3', 'UI', '3m)', 'KcNCS']
# 인식한 글자: ['6', '정관장', '홍심정환', '대요3', 'MI', 'U3', 'KcNCS']
# 인식한 글자: ['6', '정관장', '홍심정환', '대"33', 'Wai', "6a')", 'KCNCS']
# 인식한 글자: ['6', '정관장', '홍상정환', '대3', '-I', 'S무기', '~', 'kcNCS']
# 인식한 글자: ['6', '정관장', '홍심정환', '품3녀 ', 'AI"', "S대S '", "'", 'KcNCS']
# 인식한 글자: ['6', '정관장', '#몇', '홍심정환', 'WS353X', 'GI', 'Jopls', 'keNCS']
# 인식한 글자: ['6', '정관장', '홍심정환', 'M"', "'", 'N', 'e가t', 'kCNCS']
# 인식한 글자: ['6', '정관장', '홍심정환', 'Mi', "'", 'U3', 'KoNCS']
# 인식한 글자: ['6', '정관장', '홍심정환', 'A', 'N', 'KoNCS']
# 인식한 글자: ['6', '정관장', '홍심정환', '서T', 'e_이"다', "'", 'KCNCS']
# 인식한 글자: ['6', '검관상', '홍심정환', 'HT', 'a', 'kcNCS']
# 인식한 글자: ['검관?}', '홍상정환', '{', 'kcNCS']
# 인식한 글자: ['경관각', '홍상정판', '댁', '2;', 'kCNCS']
# 인식한 글자: ['경관}', '홍심정판', '', "'", 'kcNCS']
# 인식한 글자: ['경관각', '홍심정판', 'kNCS']
# 인식한 글자: ["검관'}", '홍심정판', 'l', '# ', 'kCNCS']
# 인식한 글자: ['7심', '홍심정환', 'KoNC-']
# 인식한 글자: ['7넣심', '홍심정환', 'TTi', 'KoNC-']
# 인식한 글자: ['점관장', '#', '홍심정환', 'F', '버다', 'koNC<']
# 인식한 글자: ['6', '정관장', '수청', '홍심정환', 'SSa', 'U', 'I', 'kCNC<']
# 인식한 글자: ['6', 'V', '정관장', '#퍼', '홍심정환', 'VSTS', 'YI', '오다', 'kNC<']
# 인식한 글자: ['6', 'V', '정관장', '#퍼', '홍심정환', '539,', 'T', '"스다', 'koNC<']
# 인식한 글자: ['6', '정관장', '#못', '홍심정환', '65539켜x', 'TI', '터-9', 'kcNCS']
# 인식한 글자: ['6', '정관장', '#', '홍심정환', '도3T 스', 'Wo:', '털l다', 'kcNC<']
# 인식한 글자: ['6', '정관장', '#', '홍심정환', 'SS3uT:x', '서3', '물3', 'keNC<']
# 인식한 글자: ['6', '정관장', '#몇', '홍심정환', 'S3 7포r선', 'A3', '대\'"', 'keNC<']
# 인식한 글자: ['6', '정관장', '#몇', '홍심정환', '553T3x', 'X', '동', 'kUNC<']
# 인식한 글자: ['6', '정관장', '#꽃', '홍심정환', 'V5SX', 'Xa', '그히다', 'KcNC<']
# 인식한 글자: ['6', '정관장', "'꽃", '홍심정환', 'T 8-X', '-I', '무무다', 'KcNC<']
# 인식한 글자: ['6', '정관장', '#꽃', '홍심정환', '3 5 3X', '곡', '59', 'roNcK']
# 인식한 글자: ['6', '정관장', '#못', '홍심정환', '5935', "'", '터부', 'rcNcK']
# 인식한 글자: ['6', '무:', '관', '9', '홍심정환', 'ss5 ', '어', 'kcNC<']
# 인식한 글자: ['6', '정관%', '홍심정환', 'mIS', "'", '다', 'KcNC<']
# 인식한 글자: ['0', '홍상정판', 'T요T ', '빚', 'AcNcK']
# 인식한 글자: ['6', '홍상정문', '7 조', '8', '수eNcK']
# 인식한 글자: ['0', '홍상정든', '무= 5', 'AeNes']
# 인식한 글자: ['홍상정든', '    {', '수cNC<']
# 인식한 글자: ['0', '홍심정문', 's화3 ', '수cNC<']
# 인식한 글자: ['0', '홍상정판', 'w  5 37', 'AeN6Y']
# 인식한 글자: ['0', '홍심정환', 'w s3', '오 3', '수SNC<']
# 인식한 글자: ['도{', '홍상정판', ' 무 3 ', 'AeN6K']
# 인식한 글자: ['홍상정판', ' 요  I3', '수eN6K', ':']
# 인식한 글자: [' >', '홍상정닫', ' 3오', '5eN65', "T'"]
# 인식한 글자: ['홍상정닫', '우 요= 요', 'eMX', '여']
# 인식한 글자: ['도{', '홍상정문', '- ', '5', 'eM65', '여 ']
# 인식한 글자: ['홍상정든', ': - ', 'e,O5', 'e3']
# 인식한 글자: ['홍상정든', '  ', '31']
# 인식한 글자: ['홍상정의', '왜  33', '2AO', 'T ']
# 인식한 글자: ['홍상정닫', ' {  ', '24']
# 인식한 글자: ['홍상정든', '   ', '#C']
# 인식한 글자: ['W >', '홍상정문', '요= :', '#']
# 인식한 글자: ['{', '흥상정든', '닫6 - I', '7', 'T3']
# 인식한 글자: ['홍상정문', ':ns ', 'H', '9>']
# 인식한 글자: ['홍상정:', '어( 우 3', 'H']
# 인식한 글자: ['홍상정닫', '1 =-호']
# 인식한 글자: ['홍상정:', '국쇼   :3']
# 인식한 글자: ['홍상정문', 'Ys -']
# 인식한 글자: [')', '홍상정닫', '  S:']
# 인식한 글자: ['홍상정문', "' 3"]
# 인식한 글자: ['홍상정:', ' 요']
# 인식한 글자: ['홍상정판', '쇼-요']
# 인식한 글자: ['홍상정문', 'Vu   ']
# 인식한 글자: ['도', '홍상정:', "w' -"]
# 인식한 글자: ['홍상정문', ' _ 그요']
# 인식한 글자: ['홍상정판', 'w 3고']
# 인식한 글자: ['홍상정관', '35 3']
# 인식한 글자: ["'_'", '5}', '홍심정환', '>sx )', '선']
# 인식한 글자: ["'", "{'", '홍심정환', 'T3 -1', ':']
# 인식한 글자: ["'_망", '음끈39 -', '', '홍상정환']
# 인식한 글자: ['"그망', '<?', '음 3 9 -', '홍심정환', "'`"]
# 인식한 글자: ['정관장', '<}', 'Wa신- -', '대 3', '홍상정환', '선', '39']
# 인식한 글자: ['정관장', '533', "a o -1'", 'Y: -', '대 3', '홍심정환', '2']
# 인식한 글자: ['정관장', '{', 'VWaw -사)', 'F', '홍심정환', '선c', '2']
# 인식한 글자: ['정관장', "'Vruwauni 3", 'd-', '홍삼정환', "'", 'VXVa', '439']
# 인식한 글자: ['정관장', '홍심정환', "'vroiauiv3)", 'a5w9', '~', 'WKXV교', '439']
# 인식한 글자: ["'정관장", '홍심정환', 'B새', "'", 'U"SM', '43)']
# 인식한 글자: ['정관장', '95', '홍심정환', "'MWXCMI", 'vsss', 'j기새다', "'", 'WSMn', 'V9']
# 인식한 글자: ['정산장', '홍심정환', 'VAso', 'Vorso', 'JP WI', 'si', '439']
# 인식한 글자: ['정관장', '홍심정환', "'AVMSMAWN", '기I', 'wn', '439']
# 인식한 글자: ['정관장', '~보m)', '홍심정환', 'Wnuuos', 'miiln', 'BD3새9', '43)']
# 인식한 글자: ['정관장', '~보관)', '홍심정환', 'rnwov', 'a', 'mIil', ':기3W9', 'V39']
# 인식한 글자: ['정관장', '홍심정환', "'Wmmiwoos", 'AMln', '가3N:', 'o', '43']
# 인식한 글자: ['칭관장', "'5", 'V969)', '홍상정환', 'WASII', "'SA4", '3W:', 'TWWi', '439']
# 인식한 글자: ['칭관장', '홍심정환', '"VAVsIIA', '4544', ': SW다', 'Wi', 'V']
# 인식한 글자: ['정관장', "'e", '홍심정환', '"VAVII', '4s)', 'A', '오하SW다', 'VO9']
# 인식한 글자: ['정관장', 'Te{', '홍심정환', '"AVwnuov', '하5-5다', 'KSVi', '49']
# 인식한 글자: ['정관장', '{63', '홍심정환', '"AVmer', 'GJw9', '뜻MVT', '139']
# 인식한 글자: ['정관장', '홍심정환', "'wTSs)", 'F', '하339', '밥n', 'N']
# 인식한 글자: ['정관장', '{!', '홍심정환', 'UrVRUISrI', 'milin', '가d', '39']
# 인식한 글자: ['정관장', "Y'", '홍심정환', "'WVwwtss", '9-내대', 'MMn', '39']
# 인식한 글자: ['정관장', 'S어t', '홍심정환', 'VVsauer)', 'KI교', 'J3NI', "'", '49']
# 인식한 글자: ['정관장', '<833', '홍심정환', 'Wiwuosso', 'Xon', 'J33NI', '~', '39']
# 인식한 글자: ['정관장', '홍심정환', 'Wmwuosss', 'aon', 'J33N9', '~', '499']
# 인식한 글자: ['정관장', '홍심정환', "'Kuoo)", '33새다', 'MSS', 'Wn', '3o']
# 인식한 글자: ['정관장', '홍심정환', "'VRISX", 'oin', "운'기3W9", '#', '39']
# 인식한 글자: ['정관장', '홍심정환', "'WRIOV", 'mT', 'a33N', '4O']
# 인식한 글자: ['정관장', '<Ee', '홍심정환', 'Wnusn', 'A', 'U3 w', '2', 'O']
# 인식한 글자: ['0', '정관장', '<e', '홍심정환', 'Wwuon', 'MTn', 'G33"2', '9']
# 인식한 글자: ['0', '정관장', '홍심정환', 'Vauoeva', 'AMn', 'S3"', '닫']
# 인식한 글자: ['정관장', '홍심정환', "'Wmrsn", 'mn', '3"9']
# 인식한 글자: ['정관장', "<'", '홍심정환', "'", "'V RuSX", 'mon', '다', '어,39', '4S']
# 인식한 글자: ['정관장', 'F:', '홍심정환', 'W RuISX', 'mSn', '가a', "'", 'VSo']
# 인식한 글자: ['0', '정관장', '홍심정환', 'VAVMsAu', "'e{", 'NS,39', 'mim', '49', 'V3N9', '여']
# 인식한 글자: ['정반장', '홍심정환', '"AVXN', ' -', '(oso', 'Miiln', 'a가자', 'e3', '여)', 'V']
# 인식한 글자: ['0', '정관장', '홍심정환', '"XVXN', ' -', 'moso', 'MWn', 'VD3WI', '23', '95)', '40']
# 인식한 글자: ['정산장', '홍심정환', 'Wtta', 'WYI', '가어가다-m8', '{}', '여']
# 인식한 글자: ["'정관장", '홍상정환', '6', '*o ', 'Noa', 'TN', '~']
# 인식한 글자: ['정관장', '홍심정환', '37', '어대', '', "' -;L"]
# 인식한 글자: ['0', '정관장', '홍삼정환', 'Te', '나 7', '5SNn', 'MTun', '무무el', '여']
# 인식한 글자: ['정관장', '홍심정환', "'Ce", "'", 'Vnd', 'WAi', '관가na', '0', 'ts ']
# 인식한 글자: ['정관장', '홍심정환', 'o', 'VAi', '`에n', '고무가다 식모eaa', '0', 'No Vh', '{ ve']
# 인식한 글자: ['정관장', '홍상정환', 'vAVSa', 'MAn', '무가o', '0', 'araaaaaa', '여']
# 인식한 글자: ['정관장', '홍상정환', '"', '{음4', 'Y교', '고설기앗6']
# 인식한 글자: ['정관장', '홍상정환', '8~', 'PS;4', 'Ei', '헬가ao', '0', 'aa', '차>']
# 인식한 글자: ['정관장', '홍상정환', '2', '밥Mi', 'F기n', '떼', '여>']
# 인식한 글자: ['정관장', '홍상정환', '가ae', '제 ', '_03)']
# 인식한 글자: ['농관장', '홍상정환', '~', '><', 'n부']
# 인식한 글자: ['홍심정환', '동', '6', '']
# 인식한 글자: ['정관장', '홍상정환', 'Y', '#aa다다', 'Ai', 'T 가-o']
# 인식한 글자: ['정관장', '홍심정환', "'S", 'arty', 'Wa', '?39']
# 인식한 글자: ['정관장', '홍상정환', '가', 'A', '선3345139']
# 인식한 글자: ['정관장', '홍심정환', 'Vd', '가', '주S ', '']
# 인식한 글자: ['정관장', '홍정환', 'V', 'e']
# 인식한 글자: ['정관장', '홍상정환', '2', '파X', 'd다']
# 인식한 글자: ['정관장', '9', '홍상정환', 'G3', '5다', '3 ']
# 인식한 글자: ['정관장', '홍심정환', 'a', '걱XY', '대다', "'"]
# 인식한 글자: ['0', '정관장', '홍심정환', 'oiano', '오l', ':o교', "'20가333139"]
# 인식한 글자: ['정관장', '홍심정환', 'omo', 'Iat', 'cMlin', "'2리기3시OWa%"]
# 인식한 글자: ['정관장', '홍심정환', 'Ymata', 'T에n', "'2리기3시91a%", '*']
# 인식한 글자: ['정관장', '홍상정환', 'ono', 'Tat', ';', 'TTn', "'a리기3시Tlao"]
# 인식한 글자: ['정관장', '홍심정환', 'ouo', 'dom', 'MOn', 'V33MTid@']
# 인식한 글자: ['49', '정관장', '홍심정환', 'od', 'oro대', ':3', '무o']
# 인식한 글자: ['홍심정환', '{', '주 `', '저설 ', '농근장']
# 인식한 글자: ['정관장', '홍심정환', "봄'", '_ e58']
# 인식한 글자: ['정관장', '홍심정환', '근', '<']
# 인식한 글자: ['홍심정환', 'Uu', '8>', '  8']
# 인식한 글자: ['홍상정환', '2 ~', "'"]
# 인식한 글자: ['홍상정문']
# 인식한 글자: ['홍상정문']
# 인식한 글자: ['홍상정문']
# 인식한 글자: ['홍상정문']
# 인식한 글자: ['홍상정환', '=']
# 인식한 글자: ['홍상정환', '>']
# 인식한 글자: ['정관장', '홍상정환', '3', '2', 'M히n', '2 가335낚8', '?']
# 인식한 글자: ['정관장', '홍상정환', 'oMFSC', '분iop', 'M에', "'건김기-식O Ia@", '=']
# 인식한 글자: ['6', '홍심정환', 'FC', 'onsow', 'M', "'건경가-시다ma@", '?3', '정관장', 'Ym']
# 인식한 글자: ['6', '정관장', '홍심정환', 'SMrDe', '"', '', "'건리기J시다Va@", '=']
# 인식한 글자: ['4 9', '6', '정관장', '홍심정환', 'GroR', 'T', 'ad가3M5-8', '=', '식ad']
# 인식한 글자: ['WS', '6', '정관장', '홍심정환', 'Y', 'Gruor', 'Ti', "'건경기다시3@", '=5', '(aad']
# 인식한 글자: ["'정관장", '홍심정환', 'O32', 'UR', 'Moin', '2리기-시다Ia다', '=']
# 인식한 글자: ['정관장', '홍상정환', 'Urwr', 'ADI', 'd리가--tag', '=5']
# 인식한 글자: ['U9', "'정관장", '홍심정환', 'KII', 'aa가3m5ta다', '=5']
# 인식한 글자: ['0 9', '정관장', '홍심정환', 'UM', 'aa가3m-ta', '=']
# 인식한 글자: ['0 >', '정관장', '홍심정환', '2', 'Mi', '버on', '=']
# 인식한 글자: ['관망', '홍상정환', '하적-', '29다', '=5']
# 인식한 글자: ['0 9', '홍상정환', "오'", '어하다', '=S']
# 인식한 글자: ['0 >', '홍심정환', '4', '중', '스?']
# 인식한 글자: ['홍상정환', '봄', '봄', '7 ?']
# 인식한 글자: ['9 3 @', '홍상정환', '오머', "닫S 7무'", '7', '7 ']
# 인식한 글자: ['홍상정환', 'X', '', '9 >', 'TU ?']
# 인식한 글자: ['홍상정관', '2', '9 ?']
# 인식한 글자: ['홍정든', '23']
# 인식한 글자: ['T- ?']
# 인식한 글자: ['수T7 5']
# 인식한 글자: ['수T7스 ?']
# 인식한 글자: ['당동', '수T수 ?']
# 인식한 글자: ['향', '6', '4T7 5']
# 인식한 글자: ['향잠둥', '스T7 ?']
# 인식한 글자: ['흥4동', '스T5C 5']
# 인식한 글자: ['향o', '스농5C3']
# 인식한 글자: ['향동', '스S4C5']
# 인식한 글자: ['향돈촌', '")', '우SC5']
# 인식한 글자: ['O', 'C', '스풍3 5']
# 인식한 글자: ['향장', 'F', '스S3<o']
# 인식한 글자: ['흥4o', 'C', '수풍3뜯?']
# 인식한 글자: ['향상동', 'o', '수SVC?']
# 인식한 글자: ['흥장계', '9?', '수S해(3']
# 인식한 글자: ['흥o', '', '스U3c5']
# 인식한 글자: ['향T', '떠(', "<>'(?"]
# 인식한 글자: ['흥상 ', 'FO', '<3vC5']
# 인식한 글자: ['홍상장', '수>vC5']
# 인식한 글자: ['6', '흥상정문', '<~Ncs']
# 인식한 글자: ['6', '홍상정단', 'G o2', '스eNc5']
# 인식한 글자: ['정관장', '홍심정환', 'X', '최*씨', '68', '스이Ns5']
# 인식한 글자: ['정관장', '홍심정환', 'MI', '6', '가리O-N다)', '스UNss']
# 인식한 글자: ['6', '경관강', '홍상정관', "'", '2', '스>Ns5']
# 인식한 글자: ["'", '홍심경활', 'KoNcs']
# 인식한 글자: ['7사거다', 'KoNe >']
# 인식한 글자: ['#사2다', 'KoNC >']
# 인식한 글자: ['#77', 'KoNe s']
# 인식한 글자: ['KoNes']
# 인식한 글자: ['#시저)', 'KoNes']
# 인식한 글자: ['`', '루', '홍심정립', 'KoNCs']
# 인식한 글자: [' ', '', '홍심정환', 'KoNcs']
# 인식한 글자: ['o{', '2', "'", '홍심정환', '선', '선', 'KoNcs']
# 인식한 글자: ['9느" 어: 94', 'R', "' 0 >", '홍심정환', 'KeNe3']
# 인식한 글자: ['정관장', '홍심정환', '6', 'KeNeo']
# 인식한 글자: ['재사계', '시', '홍심정환', '밥IImI', ':', 'KeNeo']
# 인식한 글자: ['신치', 'A', '홍심정환', '(Ubm', 'II', 'KeNc3']
# 인식한 글자: ['홍상정환', 's', 'K~Ne3']
# 인식한 글자: ['홍상정환', ' ', '스~Ne3']
# 인식한 글자: ['홍상정관', '흩eNe3']
# 인식한 글자: ['흥상정님', '(eNc3']
# 인식한 글자: ['흥상장', '스eNc5']
# 인식한 글자: ['S', '4e4c5']
# 인식한 글자: ['묻히', 'Kerco']
# 인식한 글자: ['동', 'Kerco']
# 인식한 글자: ['J자', '44403']
# 인식한 글자: ['43795']
# 인식한 글자: ['46793']
# 인식한 글자: ['7793']
# 인식한 글자: ['47745']
# 인식한 글자: ['46745']
# 인식한 글자: ['46743']
# 인식한 글자: ['477C3']
# 인식한 글자: ['향히', '2']
# 인식한 글자: ['향동', '2']
# 인식한 글자: ['흥임정든', '3C']
# 인식한 글자: ['흥정든', '3C']
# 인식한 글자: ['흥정', '745']
# 인식한 글자: ['향정', '44)']
# 인식한 글자: ['흥장', '9']
# 인식한 글자: ['흥장', '수']
# 인식한 글자: ['흥동', '수']
# 인식한 글자: ['향동', '=']
# 인식한 글자: ['향장']
# 인식한 글자: ['흥정:', 'TS']
# 인식한 글자: ['흥상정환']
# 인식한 글자: ['정관장', '홍심정환', 'Xoi', 'G3 u3', "여'", '2']
# 인식한 글자: ['정관장', '홍심정환', '~', 'S', 'Aoln', '9', ':3MI']
# 인식한 글자: ['0 9', '정관장', '홍심정환', 'S', 'Moi', '"고장가aM-tam']
# 인식한 글자: ['정관장', '홍심정환', 'AoI', '망다', '@S']
# 인식한 글자: ['정관장', '홍심정환', 'Aoi', '상_가-다', '여>']
# 인식한 글자: ['정관장', '홍심정환', 'Man', '"관_가다M다n8']
# 인식한 글자: ['정관장', '홍심정환', '말e', 'Wa', '선_가-다', '955']
# 인식한 글자: ['정관장', '홍심정환', 'MMI', '불V가 -자다하다', '_', '2']
# 인식한 글자: ['정관장', '홍심정환', 'MS', '전_기 -시다 Mat', '9']
# 인식한 글자: ['정관장', '홍심정환', '89', 'ASi', '전O기3d다m-l']
# 인식한 글자: ['정관장', '홍심정환', '2', 'MSI', "B'J8N", '벼', ')']
# 인식한 글자: ['정관장', '홍심정환', "''", 'MWIn', 'OO기3시다am']
# 인식한 글자: ['정관장', '홍심정환', 'MMIn', '장가-시', "'"]
# 인식한 글자: ['정관장', '홍심정환', "'", 'WWI', '-3N다 mam']
# 인식한 글자: ['정관장', '홍심정환', "'", 'Mi', 'd기 3N  mall']
# 인식한 글자: ['칭산장', '홍심정환', "'", 'AY', '(헬V기다시다aal']
# 인식한 글자: ['정관장', '홍심정환', '2', 'KWWI', '언물기al']
# 인식한 글자: ["'정관장", '홍심정환', 'AMIn', '주주가다관다다a']
# 인식한 글자: ['산장', '홍심정환', '43', 'MMWI', 'N', '오']
# 인식한 글자: ['정관장', '홍심정환', 'MTi', 'V리가-Nmal']
# 인식한 글자: ['정관장', '홍심정환', 'MTli', 'a가-Nal']
# 인식한 글자: ['정관장', '홍심정환', "'", 'A', 'SIIaaam', '9']
# 인식한 글자: ['정관장', '홍삼정환', 'MS', 'd33V', 'K', 'Sesr', 'N']
# 인식한 글자: ['정관장', '홍상정환', '2', 'MTII', 'V기m', '2']
# 인식한 글자: ['정관장', '홍삼정환', '', 'M:', 'r3-9']
# 인식한 글자: ['정관장', '홍상정환', ' 다', 'Moi', "'전경가-4OTa@", "'"]
# 인식한 글자: ['정관장', '홍상정환', '어350', 'Molin', "'전경가aMOIl", '오l']
# 인식한 글자: ['정관장', '홍심정환', 'KMI', '3298N5', '3', '2', '']
# 인식한 글자: ["'정관장", '홍삼정환', 'MMn', "'엇V가새", 'V']
# 인식한 글자: ["'정관장", '홍심정환', 'MI', 'JJ8N', '2', '', '_']
# 인식한 글자: ['정관장', '홍심정환', 'Idao', 'MM', 'd9가3NA', '담r', '']
# 인식한 글자: ["'버관V", '홍심정환', 'G1n', 'WSi', "'BO NT", "'"]
# 인식한 글자: ["'Y관 v", '홍심정환', 'Gmn', '-Si', 'm다다 ma다a다', '여>']
# 인식한 글자: ['홍심정환', 'IUII', '한다가 -NOaal']
# 인식한 글자: ['홍심정환', "'고0;'", 'IWI', 'aNTal']
# 인식한 글자: ['\'N"?', '홍심정환', "'a0;'", 'MVIII', 'MM', '']
# 인식한 글자: ['홍심정환', 'MWMII', 'I신 NIaIIII', 'NN']
# 인식한 글자: ["'a", '홍심정환', "'0;'", 'MIII', '다I시III']
# 인식한 글자: ['홍심정환', '"II', "O기'가le"]
# 인식한 글자: ['N신', '홍심정환', "'';'", 'WVII', 'U기-N다all']
# 인식한 글자: ['홍심정환', 'MVIII', 'E기기-MIlV@', '집신장', "OS'"]
# 인식한 글자: ['홍심정환', 'Iooioraiatalatl', 'MMn', '긴신기짓시터 130', '정관장', 'e']
# 인식한 글자: ["'성관장", '홍심정환', 'Faeoeramatataltt', 'MAi', '건강기하N3B0', 'Y']
# 인식한 글자: ["'정관장", '홍심정환', 'SoGrtaiaalT', 'MAi', "'건강기짓식8 130"]
# 인식한 글자: ["'성관장", '홍심정환', 'SoGrTalmalI', 'MAi', "'건강기짓식터 130"]
# 인식한 글자: ['홍심정환', 'Feoierataati', 'M', '건강기중식터 1630', "'정관장", 'Ga']
# 인식한 글자: ["'성관장", '홍상정환', 'Yosratran', 'MX', '건경기3식터 199', '액t']
# 인식한 글자: ["'상관장", '홍심정환', 'Poenatrmat', 'W국n', "'건경기J식음 1630", 'Uo']
# 인식한 글자: ["'상관장", '홍심정환', 'ooratilmatt', 'MS', '건강기밥식 390', '(']
# 인식한 글자: ["'상산장", '홍심정환', 'Foean', 'MSn', "'건강기Ju33@", '(']
# 인식한 글자: ["'상관장", '홍심정환', 'sramman', 'KXi', '건강기J식3 3@']
# 인식한 글자: ["'8선장", '홍상정환', "'n", 'AA', '233움 이']
# 인식한 글자: ['<8', '홍상정환', '"', '2', '', 'H과', '35']
# 인식한 글자: ['홍상정문']
# 인식한 글자: ['홍4정단']
# 인식한 글자: ['홍상정문']
# 인식한 글자: ['홍상정문']
# 인식한 글자: ['홍상정문']
# 인식한 글자: ['홍상정관', '스']
# 인식한 글자: ['홍상정환', '8', '=']
# 인식한 글자: ["'정관장", '홍심정환', 'ie', 'J다mma이다', 'MMn', "'긴리기3 u다5@", '스']
# 인식한 글자: ['정관장', '홍심정환', 'Urrar', 'MI', "'긴강기3시다55@", '=3', "']"]
# 인식한 글자: ['정관장', '홍심정환', 'oedtuan', 'MMn', "'건0가3N513@", '?']
# 인식한 글자: ['정관장', '홍심정환', '기다aI다', 'MMI', "'29기3N다V다@", 'E', '스D']
# 인식한 글자: ["'점관장", '홍심정환', '2', 'KMIIII', 'U-39190', '우']
# 인식한 글자: ['시신시', '홍심정환', '"VI', 'UII기 allat', '=D']
# 인식한 글자: ['홍심정한', 'a', 'T']
# 인식한 글자: ['시I기', '홍심정반', '버개 ', '=']
# 인식한 글자: ['홍심정반', 'IIIlal', '수']
# 인식한 글자: ['8사정 ', '람S']
# 인식한 글자: ['#사집 ', '7']
# 인식한 글자: ['8사집 ', '1']
# 인식한 글자: ['효사장신', 'Vo']
# 인식한 글자: ['효사집기', '7', '7']
# 인식한 글자: ["'I'", '@사장기', 'VS']
# 인식한 글자: ['신I', '#신집기', 'V9']
# 인식한 글자: ['효사집', '159']
# 인식한 글자: ['I', '#신지긴', 'V)']
# 인식한 글자: ["WI'", '#사지', 'V)']
# 인식한 글자: ['I', '#시지 기', 'V)']
# 인식한 글자: ["I'", '#사지기', 'V)']
# 인식한 글자: ["'VI", '#사집', 'M)']
# 인식한 글자: ['WII', '#시집기', 'V)']
# 인식한 글자: ['"I', '통심집기', 'M)']
# 인식한 글자: ['WMVI', '통사정가', 'MY']
# 인식한 글자: ["II'", '통심정신', 'MY', "'W'"]
# 인식한 글자: ['거 1', "'I''", '홍심정률', 'NU']
# 인식한 글자: ['홍심정만', 'N보']
# 인식한 글자: ['0', '정관장', '홍심정환', 'wxmurowa', '{TMiii', '인', '1C']
# 인식한 글자: ['정관장', ':}', '홍심정환', '또ao', 'Ti', '한I', '4HC', 'T']
# 인식한 글자: ['정관장', '{5', '홍심정환', 'Jiuroa', 'iiin', '흘JS', '9']
# 인식한 글자: ['정관장', '홍심정환', '또auroa', 'Xiin', '@디 I', '{35']
# 인식한 글자: ['정관장', '홍심정환', '또iuoa', '장iin', 'NrpN n', '{35']
# 인식한 글자: ['정관장', '{3}', '홍심정환', 'Wauron', 'TI', '@가3N', 'IO']
# 인식한 글자: ['정관장', '홍심정환', 'wxaunoxo', 'M문I', 'pt3NI']
# 인식한 글자: ['정관장', '보', '홍심정환', 'waunon', "'", 'AYn', 'N마니NI', '9', '여구', '얘']
# 인식한 글자: ['정관장', "S:'", '홍심정환', 'Wiuoo', "'", 'mIi', 'USISV', '여']
# 인식한 글자: ['정관장', "{6'", '홍심정환', "'viRuror", 'AWn', 'FSW', '여']
# 인식한 글자: ['정관장', '홍심정환', 'WiMtow)', 'Mi', 'MYWY', '2', '2', '']
# 인식한 글자: ['정관장', '홍심정환', 'W요Oe', 'A', 'WFeVA', '25']
# 인식한 글자: ['6', '정관장', '홍심정환', 'm:3', 'AII', "리'"]
# 인식한 글자: ['정관장', '홍심정환', '나aPOT', 'KMI', "하'"]
# 인식한 글자: ['6', '정관장', '홍심정환', 'mau3', 'MMII', '::', ')', '9', '여']
# 인식한 글자: ['정관장', '홍심정환', 'ynunov', "'", 'MMI', 'Jua', 'e']
# 인식한 글자: ['정관장', '홍심정환', "'", 'MMII', '일이다', 'e', '2', 'Waruisw']
# 인식한 글자: ['정관장', '홍심정환', '표 3)', "'", 'MWn', '무N', '2', '2', '']
# 인식한 글자: ['정관장', '홍심정환', 'viauron', "'", 'TYI', "'가", '9']
# 인식한 글자: ['정관장', '홍심정환', 'UIII', '부U', 'Vxgaws3', '{']
# 인식한 글자: ['정관장', '홍심정환', 'G', 'd가-', '여5', 'Twxat <3>', '']
# 인식한 글자: ['정관장', '{:', '홍심정환', 'UI', 'SrI', '2', 'Wvrcaw sx)']
# 인식한 글자: ['정관장', '홍심정환', 'UII', '2', '{35', 'Iurawsx)', " 'n'"]
# 인식한 글자: ['정관장', "{'", '홍심정환', '5', 'EaII', '2', "'xas-증", 'aaI']
# 인식한 글자: ['정관장', '홍심정환', "U'", '2', '2', "'vasx)", '하동다']
# 인식한 글자: ['정관장', '홍심정환', '~', 'MI', 'W', 'e', "'xauuisx)"]
# 인식한 글자: ['정관장', '홍심정환', 'US', '{)', 'e3', '9>', 'Wwawsx)', "a '가`"]
# 인식한 글자: ['0', '정관장', '홍심정환', 'SMI', 'IN', '9', '9', 'Wrxawsss자)', '다다']
# 인식한 글자: ['0', '정관장', 'S', '홍심정환', 'MIn', 'rI', '9', '9', 'Wwawoos)', '']
# 인식한 글자: ['6', '정관장', '홍심정환', 'MII', '다무-NW', '2', '{:5', '9', 'Wvantsn']
# 인식한 글자: ['6', '정관장', '유?!', '홍심정환', 'CYIn', '"현_기 _Iaa', '2', 'oVa" -X']
# 인식한 글자: ['6', '정관장', '홍심정환', 'MMI', '수p보 )', '2', '2', 'Wvowwsn', '리']
# 인식한 글자: ['6', '정관장', '홍심정환', 'rYII', "'회닐 )", '9', '23', 'Wxawssn)', '가다']
# 인식한 글자: ['6', '정관장', '홍심정환', 'MIn', '오S )', '여3', '9', 'Wvawssn)', '1']
# 인식한 글자: ['6', '53', '정관장', '홍심정환', "'", 'MII', "'전너기_시다", '9', 'Wxa 39']
# 인식한 글자: ['0', '53', '정관장', '홍심정환', "'", 'WMII', '숙미SV', '2', '2', 'WVNais)', '']
# 인식한 글자: ['6', '정관장', '홍심정환', 'MIII', "주주가'세I", '0', "'wxauu u ", '']
# 인식한 글자: ['0', '정관장', '홍심정환', 'WM', '이가)', '2', '9', 'Watx']
# 인식한 글자: ['6', '정관장', '홍심정환', 'U', "불'가다이다", 'e', '2', 'WxaR)', '']
# 인식한 글자: ['0', '5', '정관장', '홍심정환', 'MYII', '기요)', 'e3', '9', "'awx)", '']
# 인식한 글자: ['0', '5', '정관장', '홍심정환', 'Mn', '불화기다이다at', '3', '2', '{xav  33']
# 인식한 글자: ['0', '정관장', '홍심정환', "'", 'MYi', "'어기_의다", '여', '23', 'Wasssx)', '가']
# 인식한 글자: ['6', '정관장', '홍심정환', '2', 'Ui', 'SN', '2', 'Wwxawss)', '']
# 인식한 글자: ['6', '정관장', '홍심정환', "'", 'UII', '', 'e', "'aw ssx)", 'ai가']
# 인식한 글자: ['6', '정관장', '홍심정환', 'UI', '', '9', 'Wwassx)', '', ':가;']
# 인식한 글자: ['6', '정관장', '홍심정환', '`i', 'nSNS', 'e', "'ats3)"]
# 인식한 글자: ['6', '정관장', '홍심정환', 'MMI', '"충물기 _대I', '23', '노rr atsn']
# 인식한 글자: ['6', '정관장', '홍심정환', 'OX', '소가', '9', 'SNsw s-33)']
# 인식한 글자: ['0', '정관장', '{:', '홍심정환', 'US', '불.가', '9', '도waws ss3)']
# 인식한 글자: ['6', '정관장', '홍심정환', 'US', '다', '여7', 'waws s sx']
# 인식한 글자: ['8', '결근 ', '홍상정환', '', 'F보o', '2', 'S5', '99- -3']
# 인식한 글자: ['6', '결근 :', '홍심정환', '또3 33', 'd', '93', '9']
# 인식한 글자: ['결근 ', '홍상정환', '또" 3', '보 ', '2', 'C3']
# 인식한 글자: ["w건' ;", '홍상정환', '또: 3', "'", '2', '9 ']
# 인식한 글자: ["'그' :", '홍심정환', '또또 5', '{', '우']
# 인식한 글자: ['끝크', '홍상정환', '또: 3', '{', '스크', '7']
# 인식한 글자: ["'근 ", '홍상정환', '4 5  ']
# 인식한 글자: ['홍상정환', ' 35']
# 인식한 글자: ['흥상정환', '9 33']
# 인식한 글자: ['홍상정판', '또요니 3', '우구']
# 인식한 글자: ['정관장', '홍심정환', '또요( 33', 'H', "'", '9']
# 인식한 글자: ['정관장', '9', '홍심정환', 'Wasona', 'H', "'"]
# 인식한 글자: ['0', '8', '정관장', '홍심정환', 'Wausona', '주oilin', "'", 'pi', '9 ']
# 인식한 글자: ['정관장', '또  33', '홍심정환', 'TO', "'", '9S']
# 인식한 글자: ['정관장', 'j _ 33', '홍심정환', 'Ta', '.rSN', '-']
# 인식한 글자: ['정관장', 'Jauo3', '홍심정환', 'Mai', "'", "'", '93']
# 인식한 글자: ['정관장', 'WaSS33', '홍심정환', 'Ki', '다', '5', "'"]
# 인식한 글자: ['정관장', 'WaSS33J', '홍심정환', '다', '`Aoi', "'"]
# 인식한 글자: ['정관장', 'WaO33J', '홍심정환', '관', '93', '동con']
# 인식한 글자: ['정관장', 'm O3', '홍심정환', 'S_ ', '6', 'UAn']
# 인식한 글자: ['정관장', ':O3', '홍심정환', "'", 'n']
# 인식한 글자: ['정관장', 'wna on', 'FW', '홍심정환', 'U험', ')']
# 인식한 글자: ['정관장', 'WRIOX', '무_가다', '홍심정환', 'Vi', ' ']
# 비디오 종료
# Mean score of BLEU: 0.4792626728110599, Total Frame: 434

# %% [markdown]
# ## 실험결과 정리
#
# |품목 이름|평균 BLEU 스코어|프레임 수|
# |---|---|---|
# |Cetaphil|0.295|325|
# |만능크리너|0.88|443|
# |정관장|0.48|434|
