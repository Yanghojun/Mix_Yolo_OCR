# %% [markdown]
# # 문장 평가
# - [잘 설명해준 사이트](https://jrc-park.tistory.com/273)
# - 생성된 문장을 평가하는 방식은 크게 2가지 (Reference가 Ground truth로 보면 되는 듯)
#   1. Rouge: Reference 문장의 단어가 Generated 문장에 포함되는 정도
#      - Text Summarization
#   2. **BLEU**: Generated 문장의 단어가 Reference Sentence에 포함되는 정도
#      - Machine Translation

# %% [markdown]
# ## 코드 예시

# %%
from nltk.translate.bleu_score import sentence_bleu
reference = [["this", "is", "the", "sample"]]
candidate = ['this', "is", "the", "sample"]
score1 = sentence_bleu(reference, candidate, weights=(1, 0, 0, 0)) # 1.0

score1
# Out:
# 1.0

# %% [markdown]
# # N-gram
# - 위 sentence_bleu 함수의 weights 인자에 들어가는것이 N-gram 인자이며 (1, 0, 0, 0)은 1-gram token들로만 평가를 진행한다는 의미
#   - 1-gram
#     - this, is, the, sample
#   - 2-gram
#     - this is, is the, the sample
#   - 3-gram
#     - this is the, is the sample
#   - 4-gram
#     - this is the sample
# - gram 수가 올라갈수록 **순서를 정확히 고려**해야 하므로 높은 점수를 받기가 쉽지 않아짐

# %%
import warnings
warnings.filterwarnings('ignore')

reference = [["나는", "너를", "사랑해", "정말로"]]
candidate = ["나는", "사랑해", "정말로", "너를"]
candidate_v2 = ["나는", "사랑해", "너를", "정말로"]
gram1 = sentence_bleu(reference, candidate, weights=(1, 0, 0, 0))
gram2 = sentence_bleu(reference, candidate, weights=(0, 1, 0, 0))
gram_v2 = sentence_bleu(reference, candidate_v2, weights=(0, 1, 0, 0)) # 1.0

print(f'1-gram score: {gram1}, 2-gram score: {gram2}, 2-gram_v2 score: {gram_v2}')
# Out:
# 1-gram score: 1.0, 2-gram score: 0.3333333333333333, 2-gram_v2 score: 2.2250738585072626e-308

# %% [markdown]
# - 2-gram의 경우 "사랑해", "정말로" 를 통해 2-gram 에 포함되어 있는 문장을 맞췄지만 2-gram_v2의 경우에는 그렇지 못해서 0 값(표기상으론 아주 작은값)을 받은 걸 알 수 있음

# %% [markdown]
# # Easy-OCR BLEU 기반 성능 테스트
# - 실시간으로 이미지를 계속 읽어와서 테스트를 진행하고자 한다

# %% [markdown]
# ## 영상 저장 코드

# %%
import datetime
import cv2
    
capture = cv2.VideoCapture(0)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
record = False

while True:
    if(capture.get(cv2.CAP_PROP_POS_FRAMES) == capture.get(cv2.CAP_PROP_FRAME_COUNT)):
        capture.open(0)

    ret, frame = capture.read()
    cv2.imshow("VideoFrame", frame)

    now = datetime.datetime.now().strftime("%d_%H-%M-%S")
    key = cv2.waitKey(33)

    if key == 27:       # ESC
        break
    elif key == 26:     # Ctrl - Z
        print("캡쳐")
        cv2.imwrite("D:/" + str(now) + ".png", frame)
    elif key == 24:     # Ctrl - X
        print("녹화 시작")
        record = True
        video = cv2.VideoWriter("D:/" + str(now) + ".avi", fourcc, 20.0, (frame.shape[1], frame.shape[0]))
    elif key == 3:      # Ctrl - C
        print("녹화 중지")
        record = False
        video.release()
        
    if record == True:
        video.write(frame)

capture.release()
cv2.destroyAllWindows()
# Out:
# 녹화 시작

# %%
import easyocr
import cv2
import numpy as np
import warnings
import time
warnings.filterwarnings('ignore')
from nltk.translate.bleu_score import sentence_bleu

def BLEU_mean(source:str, ref:list):
    mean_val = 0
    count = 0
    # cam = cv2.VideoCapture(0)     # if you want to use webcam
    cam = cv2.VideoCapture(source)        # if you want to read video file
    reader = easyocr.Reader(['ko', 'en'], gpu=True)

    reference = [ref]

    while True:
        check,frame = cam.read()
        if not check:
            print("비디오 종료")
            break
        
        count += 1

        cv2.imshow('video', frame)
        result = reader.readtext(frame)
        # candidate = []

        if len(result) != 0:        # 뭔가 잡았다면
            text = []
            for obj in result:
                # bbox = obj[0]
                text.append(obj[1])
                # confidence = obj[2]
            bleu_score = sentence_bleu(reference, text, weights=(1, 0, 0, 0)) # 1.0
            
            if bleu_score != 0.0:       # 많은 예측값들 중 정답 단어를 예측한게 있다면
                mean_val += 1.0
            
            else:
                pass

            print(f"인식한 글자: {text}")
            
        key = cv2.waitKey(1)
        if key == 27:
            break

    cam.release()
    cv2.destroyAllWindows
    return mean_val / count, count

source = 'C:/Users/hojun_window/Desktop/Cetaphil.mp4'
ref = ['Cetaphil']
val, frames = BLEU_mean(source, ref)
print(f"Mean score of BLEU: {val}, Total Frame: {frames}")
# Out:
# 인식한 글자: ['Cetaphil']
# 인식한 글자: ['Cetaphil', '']
# 인식한 글자: ['(Cetaphil', 'MAo']
# 인식한 글자: ['Cetaphil', 'MA대']
# 인식한 글자: ['Cetaphil']
# 인식한 글자: ['의', 'Cetaphil', '9S3']
# 인식한 글자: ['다', 'Cetaphil', '9']
# 인식한 글자: ['Cetaphil', '9S']
# 인식한 글자: ['Cetaphil']
# 인식한 글자: ['Cetaphil', '대']
# 인식한 글자: ['Cetaphil']
# 인식한 글자: ['Cetaphil', 'Md']
# 인식한 글자: ['Cetaphil', 'Md']
# 인식한 글자: ['Cetaphil', 'Voulm']
# 인식한 글자: ['Cetaphil', "'", 'w']
# 인식한 글자: ['Cetaphil', 'Vovon', 'Aovwirislno']
# 인식한 글자: ['Cetaphil', 'Molpturiuino Loton']
# 인식한 글자: ['Cetaphil', 'Vowion', "'Aoturiuing"]
# 인식한 글자: ['Cetaphil', 'Vowon', "'Aoturiuing"]
# 인식한 글자: ['Cetaphil', 'NY', 'olpturiaino Louon']
# 인식한 글자: ['Cetaphil', 'Maluturiuino Louion']
# 인식한 글자: ['Cetaphil', 'Walpturislno Loton']
# 인식한 글자: ['Cetaphil', 'Malpturisino Lotion']
# 인식한 글자: ['Cetaphil', 'olpturiulno Lotion']
# 인식한 글자: ['Cetaphil', 'ammuriolno Lotion']
# 인식한 글자: ['Cetaphil', 'Mommturipino Lotion']
# 인식한 글자: ['Cetaphil', 'Alrisirg Lton']
# 인식한 글자: ['Cetaphil', 'Motmturiolno Lotlon']
# 인식한 글자: ['Cetaphil', "'Alrisirg L,on"]
# 인식한 글자: ['(Cetaphil', 'Momturioino Lotion']
# 인식한 글자: ['Cetaphil', 'Molpturiuino Lotion']
# 인식한 글자: ['Cetaphil', 'oloturioino lotlon']
# 인식한 글자: ['Cetaphil', 'Asturising [ ovon', 'Adw']
# 인식한 글자: ['Cetaphil', 'Mamturislno Lotion', 'OI', '새ewltn']
# 인식한 글자: ['Cetaphil', 'omturioino Lotion', '새e#NA']
# 인식한 글자: ['Cetaphil', '4신', 'Motpturislng Lotion', "'", '4I', 'Caltfs']
# 인식한 글자: ['Cetaphil', '4신', 'Motpturislng Lotion', "'", '4I', 'Faltfs']
# 인식한 글자: ['Cetaphil', 'Ya', 'Wototuriuing Lotion', 'AVW']
# 인식한 글자: ['Cetaphil', '029', 'ANursngovon']
# 인식한 글자: ['Cetaphil', '79', '_uyngron']
# 인식한 글자: ['(Cetaphil', 'PWE']
# 인식한 글자: ['Cetaphil']
# 인식한 글자: ['Cetaphil']
# 인식한 글자: ['Cetaphill']
# 인식한 글자: ['Cetaphi']
# 인식한 글자: ['Cetaphil', 'F']
# 인식한 글자: ['Cetaphil']
# 인식한 글자: ['(Cetaphil', 'v', "'"]
# 인식한 글자: ['(Cetaphil', '', "'", '다']
# 인식한 글자: ['(Cetaphil', "'", "'uriing"]
# 인식한 글자: ['(Cetaphil', 'N ', 'T', 'S ', "'ysturising"]
# 인식한 글자: ['(Cetaphil', 'Lolon', "'ysturising", 'CI']
# 인식한 글자: ['(Cetaphil', 'Vonon', 'Vyoturising', 'otyool']
# 인식한 글자: ['(Cetaphil', 'Vonon', 'Iya', '어5 >', 'yalurising', 'CID', 'VJA ASOIA', 'Won']
# 인식한 글자: ['[Cetaphil', 'Vovon', '어S >', 'Myutunsing', 'VJI AOOPI', 'Wooy', 'c']
# 인식한 글자: ['Cetaphill', 'Vovon', 'Wyd', 'OS', "'roturising", 'Noll', "'세olahl", 'Woow']
# 인식한 글자: ['(Cetaphil', 'Vowon', "' ysturising", 'Vosoor', 'Woo']
# 인식한 글자: ['Cetaphil', 'Vovon', "'Awsturising", 'Uol MoOh', 'Wooy', 'o']
# 인식한 글자: ['Cetaphil', 'OI', 'Ow', "''slurising", 'Vorao', 'Wooyw', 'rov']
# 인식한 글자: ['[Cetaphil', '실', 'Voron', "'Ayolurising", 'Vorororri', "Woo'p", 'owo']
# 인식한 글자: ['Cetaphil', '실', 'Voron', "'Ayolurising", 'Vorororri', "Woo'p", 'owo']
# 인식한 글자: ['Cetaphil', 'n', "'ysturwsinq"]
# 인식한 글자: ['Cetaphil', "'", '선retuwwng']
# 인식한 글자: ['Cetaphil', "'", '2']
# 인식한 글자: ['Cetaphil', "'", 'uwuira']
# 인식한 글자: ['(Cetaphil', 'o']
# 인식한 글자: ['(Cetaphi']
# 인식한 글자: ['CCetaph']
# 인식한 글자: ['Cetaphil', '서', 'an']
# 인식한 글자: ['[Cetaphil', '서o', 'anturttiratoe', 'gnovbsw']
# 인식한 글자: ['[Cetaphil', '0-', 'anurtuina teatoa', 'C69', 'C sV']
# 인식한 글자: ['Cetaphil', '.>', 'aaurtomrorora', 'V', 'C', 'Po']
# 인식한 글자: ['Cetaphil', 'vd', 'K urisingieso', 'C']
# 인식한 글자: ['CCetaphil', "'", " ' 대snae:n"]
# 인식한 글자: ['[Cetaphil', "'';na", '4']
# 인식한 글자: ['Cetaphil', '; ;na', '']
# 인식한 글자: ['Cetaphil', ' UnG', '7증9']
# 인식한 글자: ['Cetaphil', 'Moarrutnerolien', 'Y어 9', '089', ' -~Jrormproy', 'Gon', 'GVoVd', 'tt']
# 인식한 글자: ['Cetaphil', "'estrrsing Lo'07", '', 'moarakrorotionlo4', 'to', '069', 'Gvaryan', 'Nsoncea']
# 인식한 글자: ['Cetaphil', "'A3tirsing Lo'ian", '2009', 'atrrauonlo', 'Myp', 'o', 'os', 'Wotce']
# 인식한 글자: ['Cetaphil', "'Ac3ttising Loton", '살', 'Uoh wsion hidrnlionlot', 'Foovarra', 'MVS', '"voytny', 'Wos']
# 인식한 글자: ['Cetaphil', 'Molcturtuingtoton', '', 'Uve', 'ooonhrorouoriol', 'Wowr', "GVo'YST", 'te)']
# 인식한 글자: ['Cetaphil', "'J 요tsrtsing Loton", '2선', '039*9', 'hrorotorlol', 'coveo', 'Uvo', 'ooiyuny', 'Ow', 'Nooy']
# 인식한 글자: ['Cetaphil', "'Ara'ising Loton", '2', 'Uorero oratrorotionlol', 'cveo', '08o', 'ovoryuny', '최6e']
# 인식한 글자: ['Cetaphil', "'Aratrtsing Loton", 'e4', 'Uorerogrhrorotionlol', 'coveo', '08o', 'ovoryony', 'G6e']
# 인식한 글자: ['CCetaphil', "'Ac st,tsing { Suon", 'Uarro Onhyarauonlot', 'Moo', 'VVo', 'Gvoryddy', 'Gooyoteo']
# 인식한 글자: ['Cetaphil', 'Mototurtsino louon', 'Uornogght lydrnuionlor', 'Roororcoltoo', 'uoo', 'GVyofydoy']
# 인식한 글자: ['CCetaphil', "'A3rgsursing", 'Ped', 'Uarweighi liarnuionlo', 'hooyorroloo', " ''", 'u6a', 'ovolyony']
# 인식한 글자: ['CCetaphil', "'Arraturiuing Lowon", '203', "UJaw83 F/3rmvon V'", 'Yoo svs', 'w', 'oevYany']
# 인식한 글자: ['CCetaphil', 'oruroig', "Vo'", 'UJsrogyooon', 'reaouso', "'", '06o', 'GVvygs']
# 인식한 글자: ['CCetaphil', 'YArnurixing', "4o'", 'Gaeioroes', 'wo', 'oo', 'ovyaNy']
# 인식한 글자: ['Cetaphill', "'Aoa'urtxing", 'Nof', 'toaa', 'Weoror', 'Mv s', 'oror', 'Uso', 'Gvor/d0y', 'Vovaton']
# 인식한 글자: ['CCetaphil', "'Aornuyriwing", 'ol', 'Udt#e-', 'Voo', "'", '08n', 'Gvolrouy', 'Wiovawn']
# 인식한 글자: ['Cetaphil', "'Acnuyrtsing", 'Vil', 'oooir', 'VVo', '0vo446107', 'Wroralw']
# 인식한 글자: ['CCetaphil', "'Aoviuftsing", "'Orotisnlol", "' '", '869', 'GV8lYdny']
# 인식한 글자: ['CCetaphil', "'AOvtntsing", 'AIVa', "' '", '089', 'VoYUay']
# 인식한 글자: ['CCetaphil', "'Aontnieing", "AVo'", "''", 'VS', 'Viviyuny']
# 인식한 글자: ['CCetaphil', "'Aorsturising", 'ol', 'Voion', 'uso', 'Gvolyuny']
# 인식한 글자: ['CCetaphil', "'Aorwwlsing", 'Voon', 'ueo', '~voyany']
# 인식한 글자: ['[Cetaphil', "'AC' Yrtsing", 'sWVU', '4', "LU'", 'uoo', '~voryddy']
# 인식한 글자: ['CCetaphil', "'AC' 'urtsing", 'e6대', 'F', 'VoIOI', 'WV', 'ubo', '~vorydny']
# 인식한 글자: ['[Cetaphil', 'Moroturioing', 'No', 'Voon', '08o', 'Vvorydny']
# 인식한 글자: ['[Cetaphil', 'Motsturtsing', 'You', 'Vowon', 'WS', 'al', 'ugo', 'Gvotyday']
# 인식한 글자: ['Cetaphil', 'Iaorotruuing', 'Yos', 'Vovon', 'Us9', 'Gvofydny']
# 인식한 글자: ['CCetaphil', "'Aoiurising", 'U8a', 'o', 'IOoa', 'Goyony']
# 인식한 글자: ['CCetaphil', "'Aeururg", '5', '']
# 인식한 글자: ['Cetaphil', 'argror4']
# 인식한 글자: ['Cetaphil', '2a', "'"]
# 인식한 글자: ['Cetaphil', 'aa', "'"]
# 인식한 글자: ['Cetapha', "'", "'"]
# 인식한 글자: ['Cetapha']
# 인식한 글자: ['Cetapha']
# 인식한 글자: ['[Cetaphi']
# 인식한 글자: ['[Cetaphil', '2']
# 인식한 글자: ['[Cetaphil']
# 인식한 글자: ['[Cetaphil']
# 인식한 글자: ['[Cetaphil', '서(', "' 무3`"]
# 인식한 글자: ['[Cetaphil', '수.', 'n oiauon']
# 인식한 글자: ['Cetaphil', 'Yecu7 na Louon']
# 인식한 글자: ['Cetaphil', 'V', 'arpturiulng Louon', 'CIO']
# 인식한 글자: ['[Cetaphil', '선', 'Malaturtulne Louon', 'CID']
# 인식한 글자: ['[Cetaphil', 'N', 'Mouluftalno Louon', 'CID']
# 인식한 글자: ['[Cetaphil', 'N.', 'Moloturtuing Loulon', 'Ualil']
# 인식한 글자: ['Cetaphil', '서', 'Molaturtulne Louon', 'UaW']
# 인식한 글자: ['[Cetaphil', 'Moluturtalno Lowon', '(IN', 'NVolw']
# 인식한 글자: ['[Cetaphil', '새', 'Mooturiglno Lolion']
# 인식한 글자: ['[Cetaphil', 'N.', 'reurisino Lowon', 'CID']
# 인식한 글자: ['Cetaphil', 'urisino Loton', '(IN']
# 인식한 글자: ['[Cetaphil', '새', 'Momurislno Lotion', 'CI']
# 인식한 글자: ['[Cetaphil', "'", 'CIU', 'Vaturising']
# 인식한 글자: ['Cetaphil', 'Mooturistno Loton']
# 인식한 글자: ['(Cetaphil', 'Nc', ' pinturiting Lolon', 'N']
# 인식한 글자: ['(Cetaphil', 'N.', 'Malawurtcino Lotien']
# 인식한 글자: ['[Cetaphil', '.', 'Molmwuriaing Lotion', 'A']
# 인식한 글자: ['[Cetaphil', 'Molaturiaing Lotion']
# 인식한 글자: ['[Cetaphil', 'N', 'Molaturtaing Lotion']
# 인식한 글자: ['[Cetaphil', 'N', 'ioatuttainig Loton', '(IN']
# 인식한 글자: ['[Cetaphil', ' ', 'otmrotoa']
# 인식한 글자: ['[Cetaphil', 'N', '', 'Wonitutwing']
# 인식한 글자: ['(Cetaphil', 'N', "'", 'Wulutuing']
# 인식한 글자: ['Cetaphil', 'N', 'ot']
# 인식한 글자: ['[Cetaphil', 't']
# 인식한 글자: ['Cetaphil', 'Muly']
# 인식한 글자: ['Cetaphil', 'Mu']
# 인식한 글자: ['Cetaphil', 'Y']
# 인식한 글자: ['Cetaphil', 'O']
# 인식한 글자: ['Cetaphil', '>']
# 인식한 글자: ['[Cetaphil', 'MOI']
# 인식한 글자: ['[Cetaphil', 'we']
# 인식한 글자: ['[Cetaphil']
# 인식한 글자: ['[Cetaphil', '2o']
# 인식한 글자: ['[Cetaphi', '2']
# 인식한 글자: ["'", 'Cetapha']
# 인식한 글자: ['', '무', 'Cetepra']
# 인식한 글자: ['[Cetaphil']
# 인식한 글자: ['[Cetaphil', '사', 'Mornturtsio Loon']
# 인식한 글자: ['[Cetaphil', 'N.', 'MornturtsiorLouor']
# 인식한 글자: ['[Cetaphil', 'WYuturiatng', '{ : ']
# 인식한 글자: ['[Cetaphil', 'Mouwurtate', 'oroo']
# 인식한 글자: ['[Cetaphil', 'Wyuturiwing', 'ooo']
# 인식한 글자: ['[Cetaphil', 'Vnurtwing Lolon']
# 인식한 글자: ['[Cetaphil', 'Mouturicing', 'VoOI']
# 인식한 글자: ['[Cetaphil', "'세'ysturisinq Lotion"]
# 인식한 글자: ['[Cetaphil', "''yalurisinq Lotion"]
# 인식한 글자: ['[Cetaphil', 'N', "'4'yalurising Lotion"]
# 인식한 글자: ['[Cetaphil', "'eluritsing", '(7', ';']
# 인식한 글자: ['(Cetaphil', "'elutiairw Lotton", '(O']
# 인식한 글자: ['(Cetaphil', 'Molotuvotno loior', '(지']
# 인식한 글자: ['(Cetaphill', 'Moetutiotno Vouonl', '(지I']
# 인식한 글자: ['(Cetaphill', 'Lluoialomiomoly']
# 인식한 글자: ['(Cetaphil', 'Modlutiulwolowoll', '새', 'UI', '\'"Gllihy lrlliaw', 'II', 'IM']
# 인식한 글자: ['(Cetaphil', '다 :luciging Lowon', 'd', 'AII', 'Uo', 'hydratlionlo4 @vatydny', '(4/s) ifl', 'Ualwolohl', 'Wsovsnce', 'Wuo', 'VIol']
# 인식한 글자: ['(Cetaphil', ' ysurising Lowan', '서*', 'M', 'a', 'Vss', 'wyolrotionlor', '(1/u) ml', 'Vailwoiohl', 'GvolYdoy', 'Wovance', 'Moo', 'WWoH']
# 인식한 글자: ['(Cetaphil', 'Moislturigino Lowion', '서c', "'하", 'NSVS', 'Mo', 'wydlrotionlor', '(41!) ml', 'Vormoioht', 'Uvorydny', 'Wooyotws', 'Woo', 'MWOU']
# 인식한 글자: ['(Cetaphil', 'Moisturising Lolion', '서.', 'O_하)', "'oi", 'ErW-', 'US', 'wydrotlonlor', "(41') Inl", 'Uoht Aoloht', 'Gvoryday', 'Wvjuhrs', 'Woo', 'VWot']
# 인식한 글자: ['(Cetaphil', 'Motsturising Lolion', '`', 'MErW', 'Oo', "Wyovoulono'", "(1') il", 'Vornoonu', 'Gvoryony', 'Woyoio', 'oo', 'VWOU']
# 인식한 글자: ['(Cetaphil', 'Motsturising Lolion', 'Ln', 'w', 'uso', 'Iydratlonlor', 'Mroo', '(473) ml', 'Uoht Aolohi ', 'Gvorydny', 'Wooooo', 'MWOU']
# 인식한 글자: ['(Cetaphil', 'Motsturiging Lolion', 'e', "'", 'w', 'Iydrotlonlor', "'(473)", 'Uohi MolOht ', 'uo', 'ovorydoy', 'Wooyoio', 'Woo', 'wou', 'Vl']
# 인식한 글자: ['(Cetaphil', 'Motsturisino Lotlon', 'd', 'w', 'VS', 'Iydvotionlor', '(473) ml', 'Uohi 최oloht', 'ovoryday', 'Wovone', 'Ivoo', 'VWoU']
# 인식한 글자: ['(Cetaphil', 'Motsturiaino Lolion', 'Nde', "'d거", 'MIreWe@', 'NS', 'Wydrotlonlot', 'Mroo', '(41J) ml', 'Vohoioioht', 'ovorydsy', 'Woowvonce', 'VWOU']
# 인식한 글자: ['(Cetaphil', 'Motsturisino Lolion', 'd `', "'", 'MIr # Wee', 'uvo', 'Iydratlonlot', 'Mroo', "'(473) I7l", 'Vohoioioht', 'ovorydsy', 'Woovonco', 'VWOU']
# 인식한 글자: ['(Cetaphil', 'Motsturisino Lowion', 'e', '', 'Awo', 'Uso', 'hydrollonlot', '(N73) rl', 'Vomyoloht', 'Gvorydny', 'Woowvhnce', 'oo', 'VWOU']
# 인식한 글자: ['(Cetaphil', 'Molsturising Louion', '6', 'w', 'WVO', 'hydrollonlol', '(N)mil', 'Molooloht', 'ovoryday', 'Woolvhneo', 'Woo', 'WWOU']
# 인식한 글자: ['(Cetaphil', 'Molsturisino Lolion', '2', '어', 'Mwsnwi', 'UVO', 'Iwydltollonlol', 'od', '(43) ril', 'Mjlwooloht', '@voryday', 'Wnulhnea', 'VWOU']
# 인식한 글자: ['(Cetaphil', 'Motsturiaing Lolion', 'ooo', 'Aesmywy', 'Uve', 'wydrotlonlol', '(473) mil', '(KJh Aolaht', 'ovoryday', 'Waolvonco', 'Woo', 'VWOU']
# 인식한 글자: ['(Cetaphil', 'Mololurisino Lolion', "'", 'Aoi', 'hydrollonlot', '(473) rnil', 'U8o', 'Uoht Aolaht', 'ovofyday', 'Wooivonco', 'wow', 'VWoL']
# 인식한 글자: ['(Cetaphil', 'Molslurising Lotion', 'Ad', 'Uso', 'hydvhllonlol', '(473) r7l', 'Nontwatoht', 'ovolyday', 'Woovonco', 'Woa', 'VWoU']
# 인식한 글자: ['(Cetaphil', 'Moisturising Lotlion', "'", 'Adt', 'so', 'hydinulonlol', "'(473) rTil", 'w', 'Momwatoht', 'ovolygay', 'Woolonco', 'Woa', 'VWOU']
# 인식한 글자: ['(Cetaphil', 'Moisturising Lotion', '어어lg', 'na', 'Ntltye', 'hydiotlon lor @voryday Vse', 'IT', 'Nonyoloht', 'Hooivonco', 'Noo', 'MWOU', "(4S)'"]
# 인식한 글자: ['(Cetaphil', 'Moisturising Lotlon', '불다', 'Asmlye', 'hydiotlon lor ovoryday usq', 'leu', "(47') vL", 'Vowolahu', 'Hoovonco', 'MWOU']
# 인식한 글자: ['(Cetaphil', 'Moisturising Lotlon', '7 >', 'Mdwws', 'Iydtolionlol', 'ovoryday vsq', '(/)) wl', 'Uor Aolohl', 'Woowonco', 'woo', 'VWoL']
# 인식한 글자: ['[Cetaphil', 'MoiswunisingLollon', '서.;', '대 #다', '8s', 'Wdiotorol', '(Ay)tl', 'Voo Aorora', 'ovoorony', 'Vooioco', 'Noo', 'WWOH']
# 인식한 글자: ['[Cetaphil', 'Molowunsino Lolior', '서', 'Wdosioroi', 'Nroo', '(y) wa', 'Vrooogra', 'ovorowy', 'hoovo', 'WGH']
# 인식한 글자: ['[Cetaphil', 'Wolotunsing Lolon', '', 'Naoion ol oroYary', 'WA', "Vo' rSI", 'hogvro', 'Voo', 'WOUSD)']
# 인식한 글자: ['[Cetaphil', 'Morotursnorouon', '709', '근 v]6', 'P', 'ocos', 'evs', 'Nes', 'owowa']
# 인식한 글자: ['(Cetaphil', '사WisngLovos', '어3', '8w6w  ']
# 인식한 글자: ['(Cetaphil', " $ 급 '", '9']
# 인식한 글자: ['(Cetaphi', '{', "'"]
# 인식한 글자: ['Cetaphi']
# 인식한 글자: ['(Cetaphil']
# 인식한 글자: ['[Cetaphil', 'a', 'eKo: 7I']
# 인식한 글자: ['[Cetaphil', "'aeturoing", "V'", 'WVo', 'W7 M+Ohl hyorouionlnl', 'Rontonralus', '"oU(ATS) mt', 'Vovon', 'ovolyooy']
# 인식한 글자: ['[Cetaphil', 'oyturising', '냉ot"sioh hydrolionlot', 'Moe', '"oz(ns)\'', 'Vowon', '0so', 'ovolyooyt', 'Rsotonca', 'IV']
# 인식한 글자: ['[Cetaphil', "'Aayuriaing", '닫다', '5: #wyoh hydrotionor', 'Wyo', 'VKSZ (473) mL', 'VOOI', 'Gso', 'ovofyooy', 'Ssgrorco']
# 인식한 글자: ['[Cetaphil', '"aelurtoing', 'Uo: rwohi hydrolionlor', 'Wvo', '"Koz(47S)', 'VooI', 'Voo', 'ovoryday', 'Voolorce', 'm']
# 인식한 글자: ['[Cetaphil', "'Aa surising Louon", 'dMa WFI', "'", '0oo', 'Uaht twohi hydrotionlol', 'Veo', '(7) T', 'Vvorydoy', 'Woaioo', 'VWOH']
# 인식한 글자: ['[Cetaphil', 'Morturtslno Louon', '저', 'M', "5rs3h hydtotionlo'", 'weo', '(sTi)mt', '0oo', 'Gvofyday', 'Woyorco', 'WOH']
# 인식한 글자: ['[Cetaphil', "'E su#sing Lowon", 'eml', 'o', 'Bwosnn']
# 인식한 글자: ['(Cetaphil', 'wcuretrororon', 'Swo:']
# 인식한 글자: ['Cetaphil', '무 3']
# 인식한 글자: ['Cetaphil', '=']
# 인식한 글자: ['Cetaphi', '제', '=']
# 인식한 글자: ['Cetapha']
# 인식한 글자: ['(Cetaphi', 'd']
# 인식한 글자: ['[Cetaphil', "'o("]
# 인식한 글자: ['[Cetaphil', 'Eufiei9 Lotic s', 'vue', '~e관Nv s', 'ey', 'No', '어 어J 9']
# 인식한 글자: ['[Cetaphil', 'MEuqiuing Lotic?', 'de', 'at', 'Ves', '늙어ovra', 'w']
# 인식한 글자: ['[Cetaphil', 'sturising Lotion', 'V', '(', 'teonlydrosbi', 'N입', '내', 'te', 'Woe']
# 인식한 글자: ['[Cetaphil', 'Tys{urising Lotior', 'CI', 'gllwydralioro4', 'Uor Mo', '8s6', '싸wy', 'Woovorrg', 'Woo']
# 인식한 글자: ['[Cetaphil', 'Motolufising Loton', '서', 'Ur', 'wydvalion', 'ovoryany', 'Voo', 'Uaht wololt', 'No', 'Wmjvonco']
# 인식한 글자: ['[Cetaphil', 'Movsturising Lotion', 'Uso', 'hydrotion lol', 'Moo', 'Uoht woloht', 'Uvoryday', 'Wolvonco']
# 인식한 글자: ['[Cetaphil', 'Vorslurising Lotion', "'", 'hydrollonlol', 'Volwovoht', 'Uo', 'volyday', 'Woolvane o', 'Ivo']
# 인식한 글자: ['[Cetaphil', 'Molrluriaing Lolon', '{>', 'A', 'hydrotlon lor @volydoy', 'Uolwoaloht', 'Uso', 'Vooioneo', 'Wvo']
# 인식한 글자: ['[Cetaphil', 'Molsluriaing Lollon', 'N.', "'터", '4e', 'wydtolonlot', 'Uaht wicloht', '0s9', 'ovorydny', 'Wooonco', 'Woo']
# 인식한 글자: ['[Cetaphil', 'Molsturising Lowon', 'No', '', 'l', 'Uso', 'hydtallonlot ovorydny', 'Wohtwotoll', 'Wovovonco', 'Woo']
# 인식한 글자: ['[Cetaphil', 'Molslurisino bolon', '닦', 'WJl', '__', 'Us', 'hydrotlonlot @Yerydny', '44', 'Woll otohl', 'Woowvono', 'Woo']
# 인식한 글자: ['[Cetaphil', 'Molulurisino Louon', 'N', '(', "'_", 'n', 'hydrotlonlol', 'Wr', 'Wohlwololt', 'o', 'ovorydny', 'Woovono']
# 인식한 글자: ['[Cetaphil', 'Mololurising bolion', '(', 'NJWa', 'NS', 'Iydlrotlonlul', 'wus', 'Uoll wololil', 'ovoryay', 'Woovono']
# 인식한 글자: ['[Cetaphil', 'Mololurising bolion', '(', 'NJWa', 'NS', 'Iydlrotlonlul', 'wus', 'Uoll wololil', 'ovoryay', 'Woovono']
# 인식한 글자: ['(Cetaphil', 'uitsirg Lolitif', '(IN', 'Wi']
# 인식한 글자: ['(Cetaphill', 'Muiolurielmololibaly', '1I']
# 인식한 글자: ['(Cetaphil', '",AI:IIU ( oMn']
# 인식한 글자: ['[Cetaphil', 'N', 'Molmurtoino lowon']
# 인식한 글자: ['[Cetaphil', 'Motuturtsino lowon']
# 인식한 글자: ['[Cetaphil', 'Mototurleino Nouon']
# 인식한 글자: ['[Cetaphil', 'N.', 'Moloturisino Loton']
# 인식한 글자: ['[Cetaphil', 'N', 'Brsturising Louion']
# 인식한 글자: ['[Cetaphil', 'Brsturising Lotion']
# 인식한 글자: ['=', '[Cetaphil', 'Motturtsinotowon']
# 인식한 글자: ['[Cetaphil', 'Vsuluing Lotion']
# 인식한 글자: ['_', '[Cetaphil', 'Vuiviroioxon', '사']
# 인식한 글자: ['Cetaphi']
# 인식한 글자: ['무', 'Cetapra']
# 인식한 글자: ['Cetapha', '7I']
# 인식한 글자: ['Cetaphil', '273']
# 인식한 글자: ['dTng', 'Cetaphil', "'"]
# 인식한 글자: ['8 uing', 'Cetaphil', "'"]
# 인식한 글자: ['ulunuing', 'Cetaphil', "'"]
# 인식한 글자: ["'A;Mlunging", 'Cetaphil', 'ono']
# 인식한 글자: ["'Aurlunuing", 'Cetaphil', 'VoSI']
# 인식한 글자: ['[Cetaphil', "'Ayeluruing", 'VooI']
# 인식한 글자: ["'Airalurising", '|', 'Cetaphil', 'VoOI']
# 인식한 글자: ['[Cetaphil', "'Airalurising", 'N6어', 'Voo']
# 인식한 글자: ['[Cetaphil', "'Auygturising", 'N', 'Voton']
# 인식한 글자: ['[Cetaphil', "'ielutiuing", '(기', "'"]
# 인식한 글자: ['[Cetaphil', 'Mntuti로ing', '(II', "' "]
# 인식한 글자: ['[Cetaphil', '\'A\' e\'utiaing [ Drtu"', '(II']
# 인식한 글자: ['[Cetaphil', "'ewrisinig", '(I', '버I', '(y  #,e+gLM ly Mallii"li"', 'O 9', 'Wa', 'WU (NI시1', 'WWV', 'VoUI', 'WVeVuy']
# 인식한 글자: ['[Cetaphil', "'E'wtsiwd", '(II', 'Nritaseiibl hqtltaliist Vt"', 'We', 'W(NIS)IIl', " ''", 'MVe', 'VinY', 'WV터', 'VII', 'Nou']
# 인식한 글자: ['Aonlurising', 'NAEW', 'Fn', 'Vtweinhihydrntionlor', 'Yaoinrralior', '(시)', 'Cetaphil', "[''0';", 'Geo', 'UVolyony', 'VWOU', 'WM']
# 인식한 글자: ['Morowurioinig', 'AauIV', "'", 'Ut woiah lydiotionlor', '"O2(AIs) ml', 'Cetaphil', 'VoSI', 'WVS', 'UVolydlny', 'Wooyhr %', 'Nvoe']
# 인식한 글자: ['[Cetaphil', 'Morowuriotng', 'NMVlV', 'o', 'Nali #eiGhlvdtollon lor', 'Wwolioo', '"o2(AIS) mil', 'Voron', 'WVO', 'Gvurydny', 'WMJ"']
# 인식한 글자: ['Wororirioing', 'W:', '(자', "'", 'Uuraoiohlqdiollon lol', 'Wooyor @', 'Cetaphil', 'Voiion', 'Nsd', 'WVO', '@Vorydny', 'Woo']
# 인식한 글자: ['[Cetaphil', 'ourising', '(자K', 'Uohi#oighlvytlinticin lol', 'WMuio @lvo', 'Voon', 'WVa', '4e 빵 ;', 'VVP', '@varydny']
# 인식한 글자: ['[Cetaphil', "'AoMurising", 'OID', 'Mariwoljh lvrctotlon lol', 'Wvurorralue', 'VOSI', 'As3VVr', 'Goo', 'GVoyydlay']
# 인식한 글자: ['[Cetaphil', "'onluricing", 'UI', 'Narwotylit lycltotitif lw', 'owow olioe', 'Voo', 'AVW', 'Woe', 'GVulyilny']
# 인식한 글자: ['[Cetaphil', "'urtrisinq", 'UII', '(IAlv Vil', 'Voior', 'GVVI']
# 인식한 글자: ['[Cetaphil', "'orturlsinq", '(N', 'Voo']
# 인식한 글자: ['[Cetaphill', 'Monturlainq', 'UII', 'Voio']
# 인식한 글자: ["'Aorturising", '서', 'Cetaphil', 'Voo', 'w']
# 인식한 글자: ['[Cetaphil', 'Moruiaing', '4C', 'W', 'Voof', 'Nr']
# 인식한 글자: ['[Cetaphil', "'Ainluvising", 'Nd', '새다', "Y'"]
# 인식한 글자: ['[Cetaphil', "'Aoralurioing", '새', 'VoOI']
# 인식한 글자: ['Cetaphil', "'Aoulutising", 'W', "C''", 'M"']
# 인식한 글자: ['[Cetaphil', 'Morwtioine', 'Volion']
# 인식한 글자: ['(Cetaphil', 'Aosturising', 'VoVoh']
# 인식한 글자: ['(Cetaphil', 'Asturitsing', 'Voo']
# 인식한 글자: ['(Cetaphil', 'oarrgrouon']
# 인식한 글자: ['(Cetaphil', 'orororon']
# 인식한 글자: ['(Cetaphil', 'wyrsrg', "'"]
# 인식한 글자: ['(Cetaphil', 'no하e', "'"]
# 인식한 글자: ['[Cetaphil', 'Aosurisng', 'Noion']
# 인식한 글자: ['[Cetaphil', "A33'urlsng", 'Moron']
# 인식한 글자: ['[Cetaphil', "Aors'arising", 'AaC', " ''"]
# 인식한 글자: ['[Cetaphil', 'orsturising Lolion', 'N대alV']
# 인식한 글자: ['(Cetaphil', 'orturising Loron']
# 인식한 글자: ['Cetaphi', ' ;']
# 인식한 글자: ['(.교']
# 인식한 글자: ['(하']
# 인식한 글자: ['(둑']
# 인식한 글자: ['Ca교']
# 인식한 글자: ['CCetaphil', '']
# 인식한 글자: ['CCetaphil', '2']
# 인식한 글자: ['[Cetaphil', '서.', 'MorsturiuinoLolon', 'CI', 'I']
# 인식한 글자: ['[Cetaphil', '서', 'Motsturiaing Lolion']
# 인식한 글자: ['[Cetaphil', "V'", 'Motstutiting Lolion', 'Voll']
# 인식한 글자: ['[Cetaphil', 'Motsturluing otion', 'Uuht']
# 인식한 글자: ['[Cetaphil', 'Molsturiuing Lotion', '2', 'Nonl']
# 인식한 글자: ['(Cetaphil', "N '", 'Motsturising Louion', '']
# 인식한 글자: ['[Cetaphil', '서', 'Motsturising Louion', "'", '4']
# 인식한 글자: ['[Cetaphil', "26'", 'Motsturising Louion', "'", 'ANIN']
# 인식한 글자: ['[Cetaphil', '선', 'Motsturising Lotion', '45MUs', '2']
# 인식한 글자: ['CCetaphil', '4 ', 'surisng Louor']
# 인식한 글자: ['CCetaphil', 'guonon']
# 인식한 글자: ['Cetaphi', "' `"]
# 인식한 글자: ['[Cetaphil', 'Ko', "'"]
# 인식한 글자: ['[Cetaphil', ' __']
# 인식한 글자: ['Cetaphil', '새', 'Nrturising Lalon']
# 인식한 글자: ['[Cetaphil', 'Nd', 'Lysturislng Lolon', "'"]
# 인식한 글자: ['[Cetaphil', 'Marpurislno Louibn', 'CII']
# 인식한 글자: ['Cetaphil', 'reurising Lolon', 'Mo', '(시시']
# 인식한 글자: ['[Cetaphil', 'N', '"eurising Lolor', "'", 'NoWV9']
# 인식한 글자: ['[Cetaphil', 'N', 'MoroturialnoLolion', '(o', 'NWM ']
# 인식한 글자: ['Cetaphil', 'N', 'jstrising Lolon', 'CI', 'NwVi MSIull']
# 인식한 글자: ['(Cetaphil', 'Molmturiuii lalion', 'NVe', "'#EIIihi hatleililiil e리", 'UI', 'NIVV']
# 인식한 글자: ['(Cetaphil', 'Moluluyiaiioylolion', 'Nes', 'I#eltlile"latlrnlel a#\'{"', 'UI', 'NNl']
# 인식한 글자: ['[Cetaphil', "'yturisirig Lolon", '새', 'hylolionlol @Veyalyus', 'Wua', 'Niliwolilit', 'Woavnww ~', 'VWo']
# 인식한 글자: ['[Cetaphil', 'Motsturtsing Lolion', '서 ', '5', 'w', 'hydtolion lol @Yoryday VA', '(o', 'Uohtwolaht', 'Woovono', 'no', 'VIoU']
# 인식한 글자: ['[Cetaphil', 'Molsturising Lotion', '서', "'g", 'ANinwoe', 'hydrotion ior ovoryday vo', 'Nroo', '(in', 'Uahtwolaht', 'Waavanco', 'IOU']
# 인식한 글자: ['[Cetaphil', 'Molsturising Lotion', '', 'F', 'Airtoe', 'hydrotion tor @vorydayvio', '다', 'Uohtwoiaht', 'Woavonco', 'Woo', 'VVO']
# 인식한 글자: ['[Cetaphil', 'Molsturising Louion', '새', 'v', 'hydrolion or ovoryday', 'Vroo', "' ", 'Nahlwoloht', 'Vo', 'Waoivonco']
# 인식한 글자: ['[Cetaphil', 'Moisturising Louion', "' ", 'ANrows', 'hydrotion', 'overyday', "'", 'Uahtwoloht', 'U8o', 'Non', 'Waovonco', 'Mvo']
# 인식한 글자: ['[Cetaphil', 'Moisturisino Louon', 'N>', "'", 'Nde', 'hydvouonlor ovorydayurg', "'", 'Uuht Noloht', 'Woolvonco', 'Wvo']
# 인식한 글자: ['(Cetaphil', 'Moisturisino Louon', 'N', "'", 'Nrrwv', 'Vidolcm kA Vroryday', 'Nrjl nprya', 'Wmuyomo', 'woo']
# 인식한 글자: ['(Cetaphil', 'Moisturisino Louon', 'No', '(', "'", 'Nrru', 'Viloronln', 'Nrjlns yA', 'VdVoar', 'Woyyoie', 'Nos']
# 비디오 종료
# Mean score of BLEU: 0.2953846153846154, Total Frame: 325

# %% [markdown]
# ## 실험결과 정리
#
# |품목 이름|평균 BLEU 스코어|프레임 수|
# |---|---|---|
# |Cetaphil|0.295|325|
