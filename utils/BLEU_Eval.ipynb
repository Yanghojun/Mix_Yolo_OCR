# %% [markdown]
# # 문장 평가
# - [잘 설명해준 사이트](https://jrc-park.tistory.com/273)
# - 생성된 문장을 평가하는 방식은 크게 2가지 (Reference가 Ground truth로 보면 되는 듯)
#   1. Rouge: Reference 문장의 단어가 Generated 문장에 포함되는 정도
#      - Text Summarization
#   2. **BLEU**: Generated 문장의 단어가 Reference Sentence에 포함되는 정도
#      - Machine Translation

# %% [markdown]
# ## 코드 예시

# %%
from nltk.translate.bleu_score import sentence_bleu
reference = [["this", "is", "the", "sample"]]
candidate = ['this', "is", "the", "sample"]
score1 = sentence_bleu(reference, candidate, weights=(1, 0, 0, 0)) # 1.0

score1
# Out:
# 1.0

# %% [markdown]
# # N-gram
# - 위 sentence_bleu 함수의 weights 인자에 들어가는것이 N-gram 인자이며 (1, 0, 0, 0)은 1-gram token들로만 평가를 진행한다는 의미
#   - 1-gram
#     - this, is, the, sample
#   - 2-gram
#     - this is, is the, the sample
#   - 3-gram
#     - this is the, is the sample
#   - 4-gram
#     - this is the sample
# - gram 수가 올라갈수록 **순서를 정확히 고려**해야 하므로 높은 점수를 받기가 쉽지 않아짐

# %%
import warnings
warnings.filterwarnings('ignore')

reference = [["나는", "너를", "사랑해", "정말로"]]
candidate = ["나는", "사랑해", "정말로", "너를"]
candidate_v2 = ["나는", "사랑해", "너를", "정말로"]
gram1 = sentence_bleu(reference, candidate, weights=(1, 0, 0, 0))
gram2 = sentence_bleu(reference, candidate, weights=(0, 1, 0, 0))
gram_v2 = sentence_bleu(reference, candidate_v2, weights=(0, 1, 0, 0)) # 1.0

print(f'1-gram score: {gram1}, 2-gram score: {gram2}, 2-gram_v2 score: {gram_v2}')
# Out:
# 1-gram score: 1.0, 2-gram score: 0.3333333333333333, 2-gram_v2 score: 2.2250738585072626e-308

# %% [markdown]
# - 2-gram의 경우 "사랑해", "정말로" 를 통해 2-gram 에 포함되어 있는 문장을 맞췄지만 2-gram_v2의 경우에는 그렇지 못해서 0 값(표기상으론 아주 작은값)을 받은 걸 알 수 있음

# %% [markdown]
# # Easy-OCR BLEU 기반 성능 테스트
# - 실시간으로 이미지를 계속 읽어와서 테스트를 진행하고자 한다

# %% [markdown]
# ## 영상 저장 코드

# %%
import datetime
import cv2

device_id = 1

capture = cv2.VideoCapture(device_id)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
record = False

while True:
    if(capture.get(cv2.CAP_PROP_POS_FRAMES) == capture.get(cv2.CAP_PROP_FRAME_COUNT)):
        capture.open(device_id)

    ret, frame = capture.read()
    cv2.imshow("VideoFrame", frame)

    now = datetime.datetime.now().strftime("%d_%H-%M-%S")
    key = cv2.waitKey(33)

    if key == 27:       # ESC
        break
    elif key == 26:     # Ctrl - Z
        print("캡쳐")
        cv2.imwrite("D:/" + str(now) + ".png", frame)
    elif key == 24:     # Ctrl - X
        print("녹화 시작")
        record = True
        video = cv2.VideoWriter("D:/" + str(now) + ".avi", fourcc, 20.0, (frame.shape[1], frame.shape[0]))
    elif key == 3:      # Ctrl - C
        print("녹화 중지")
        record = False
        video.release()
        
    if record == True:
        video.write(frame)

capture.release()
cv2.destroyAllWindows()
# Out:
# 녹화 시작

# %% [markdown]
# ## 성능 산출 코드

# %%
import easyocr
import cv2
import numpy as np
import warnings
import time
warnings.filterwarnings('ignore')
from nltk.translate.bleu_score import sentence_bleu

def BLEU_mean(source:str, ref:list):
    mean_val = 0
    count = 0
    # cam = cv2.VideoCapture(0)     # if you want to use webcam
    cam = cv2.VideoCapture(source)        # if you want to read video file
    reader = easyocr.Reader(['ko', 'en'], gpu=True)

    reference = [ref]

    while True:
        check,frame = cam.read()
        if not check:
            print("비디오 종료")
            break
        
        count += 1

        cv2.imshow('video', frame)
        result = reader.readtext(frame)
        # candidate = []

        if len(result) != 0:        # 뭔가 잡았다면
            text = []
            for obj in result:
                # bbox = obj[0]
                text.append(obj[1])
                # confidence = obj[2]
            bleu_score = sentence_bleu(reference, text, weights=(1, 0, 0, 0)) # 1.0
            
            if bleu_score != 0.0:       # 많은 예측값들 중 정답 단어를 예측한게 있다면
                mean_val += 1.0
            
            else:
                pass

            print(f"인식한 글자: {text}")
            
        key = cv2.waitKey(1)
        if key == 27:
            break

    cam.release()
    cv2.destroyAllWindows
    return mean_val / count, count

source = 'C:/Users/hojun_window/Desktop/딱풀_편집본.mp4'
ref = ['딱풀']
val, frames = BLEU_mean(source, ref)
print(f"Mean score of BLEU: {val}, Total Frame: {frames}")
# Out:
# 인식한 글자: ['Aoo', '딱물', '{;', '무']
# 인식한 글자: ['Ao)', '딱물', '무']
# 인식한 글자: ['AV)', '딱물', '닦껑']
# 인식한 글자: ['Ao)', '딱물', '무']
# 인식한 글자: ['Aos', '딱물', '다7']
# 인식한 글자: ['AIOY', '딱풀', '모']
# 인식한 글자: ['AMOY', '딱풀', '모']
# 인식한 글자: ['Fa무>', '딱물', '유:']
# 인식한 글자: ['딱물', '[']
# 인식한 글자: ['딱물', '닦']
# 인식한 글자: ['딱물', '모']
# 인식한 글자: ['Ja', '딱물', '닦']
# 인식한 글자: ['Ja', '딱물', '유:']
# 인식한 글자: ['a', '딱물', '무']
# 인식한 글자: ['FaMSO', 'Ja', '딱풀', '다']
# 인식한 글자: ['AIOY', 'Ja', '딱풀', '다K']
# 인식한 글자: ['Moy', 'Jn', '딱풀', 'PU']
# 인식한 글자: ['Moy', 'n', '딱풀', 'C']
# 인식한 글자: ['Moy', 'n', '딱풀', 'C']
# 인식한 글자: ['ani', 'Moj', '미물']
# 인식한 글자: ['Nrl', 'Moy']
# 인식한 글자: ['N)']
# 인식한 글자: ['Janigen', 'Cal', 'AoJ', '딱물']
# 인식한 글자: ['langen', 'Cal', 'AoJ', '딱물', '우:']
# 인식한 글자: ['jangen', 'Cal', 'Aos', '딱물', '4:']
# 인식한 글자: ['janigen', 'CeI', 'AoJ', '딱물', '우:']
# 인식한 글자: ['Jangen', 'CeI', 'AMos', '딱풀', 'R:']
# 인식한 글자: ['Jangen', 'CeI', 'Aos', '딱물', '우구:']
# 인식한 글자: ['Jangen', 'C', 'AoJ', '딱물', '우의:']
# 인식한 글자: ['서클', '수o)', '딱물']
# 인식한 글자: ['서클', '수o)', '딱물']
# 인식한 글자: ['Jangen', '수6J', '딱물', '7:']
# 인식한 글자: ['Jangen', 'A)', '딱물', '우구:']
# 인식한 글자: ['anigen', 'A)', '딱물', '우구:']
# 인식한 글자: ['Jangen', 'CI', 'AMo3', '딱풀', '우표:']
# 인식한 글자: ['Janigen', 'CeI', 'AoJ', '딱풀', '우요:']
# 인식한 글자: ['Janigen', 'CeI', 'AMo3', '딱풀', '우요:']
# 인식한 글자: ['Janigen', 'CeI', 'AoJ', '딱물', '우요성']
# 인식한 글자: ['Janigen', 'CaI', 'AMo3', '딱물', '구성']
# 인식한 글자: ['lanigen', 'CCI', 'Aos', '딱풀', '구성']
# 인식한 글자: ['lngen', 'Cal', 'Aos', '딱풀', '우성']
# 인식한 글자: ['Jngen', '4o3', '딱풀', '우성']
# 인식한 글자: ['Jngen', '4o3', '딱풀', '우의성']
# 인식한 글자: ['jingen', 'Ce', 'Ao5', '딱풀', '우표성']
# 인식한 글자: ['4o3', '딱물', '우요:']
# 인식한 글자: ["'설구", '4J', '딱물', '우요성']
# 인식한 글자: ['nj3', 'Ao)', '딱물', '우요:']
# 인식한 글자: ['Jangen', 'Ao3', '딱물', '우:']
# 인식한 글자: ['Jangen', 'Aos', '딱물', '우:']
# 인식한 글자: ['Jangen', 'CeI', 'Mos', '딱물', '9:']
# 인식한 글자: ['aangen', 'Ce', 'Mos', '딱물', 'F성']
# 인식한 글자: ['Jangen', 'CeI', 'Mos', '딱물', '다성']
# 인식한 글자: ['Jange ', 'CeL', 'Mos', '딱물', '맺성']
# 인식한 글자: ['Janget', 'CeI', 'Mos', '딱물', '우다성']
# 인식한 글자: ['Janget', 'CeI', 'Mos', '딱물', '우다성']
# 인식한 글자: ['Jinge', 'Cel', 'AoS', '딱물', '무4:']
# 인식한 글자: ['Jange', 'Ce', 'Aos', '딱물', ': ', '우:']
# 인식한 글자: ['Jange', 'Ca', 'AS', '딱물', '무:']
# 인식한 글자: ['Jngd', 'Ce', 'AoS', '딱물', '9:']
# 인식한 글자: ['aang', 'Aos', '딱물', '::']
# 인식한 글자: ['aang', 'AoS', '딱물', 'F8']
# 인식한 글자: ['angt', 'Ge', 'AoJ', '딱물', 'F']
# 인식한 글자: ['Jongsl', 'Aos', '딱물', '748']
# 인식한 글자: ['.ngt', 'AoJ', '딱물', '98']
# 인식한 글자: ['Jjang', 'AoJ', '딱물', '5']
# 인식한 글자: ['aang', 'AoJ', '딱물', ':8']
# 인식한 글자: ['aang', 'AoJ', '딱물', ':8']
# 인식한 글자: ['lang', 'AoJ', '딱물', '5:']
# 인식한 글자: ['ani', 'AoJ', '딱물', '5']
# 인식한 글자: ['ani', 'AoJ', '딱물', '5']
# 인식한 글자: ['Jni', 'Aoy', '딱물', '5:']
# 인식한 글자: ['Jn', 'AoJ', '딱물', '5']
# 인식한 글자: ['.n', 'AoS', '딱물', '5:']
# 인식한 글자: ['r', 'AoS', '딱물', '5']
# 인식한 글자: ['해', 'AoS', '딱물', 'PU']
# 인식한 글자: ['J히', 'AoS', '딱물', '5']
# 인식한 글자: ['J', 'AMoS', '딱물', '모']
# 인식한 글자: ['AoS', '딱물', '모']
# 인식한 글자: ['AoS', '딱물', '닦']
# 인식한 글자: ['AoJ', '딱물', '5:']
# 인식한 글자: ['Aoy', '딱물', '닦']
# 인식한 글자: ['Aos', '딱물', '우']
# 인식한 글자: ['AMos', '딱물', '닦']
# 인식한 글자: ['AoS', '딱물', '5K']
# 인식한 글자: ['AoJ', '딱물', '우:']
# 인식한 글자: ['Aoy', '딱물', 'P']
# 인식한 글자: ['AoJ', 'P', '딱물']
# 인식한 글자: ['AoJ', '딱물']
# 인식한 글자: ['AoJ', '따물', 'P']
# 인식한 글자: ['MoJ', '딱물', '모']
# 인식한 글자: ['MoJ', '딱물', '모']
# 인식한 글자: ['AoJ', '딱물']
# 인식한 글자: ['MoJ', '딱물', '5:']
# 인식한 글자: ['AoJ', '딱물', '5:']
# 인식한 글자: ['AoJ', '딱물']
# 인식한 글자: ['MoJ', '딱물', '우:']
# 인식한 글자: ['MoJ', '따물', '우']
# 인식한 글자: ['AoJ', '딱물', '5:']
# 인식한 글자: ['MoJ', '딱물', 'P']
# 인식한 글자: ['AoJ', '딱물', '5:']
# 인식한 글자: ['AoJ', '딱물', '9:']
# 인식한 글자: ['AoJ', '딱물', '5:']
# 인식한 글자: ['AoJ', '딱물', '5:']
# 인식한 글자: ['AoJ', '딱물']
# 인식한 글자: ['AoJ', '딱물', '5']
# 인식한 글자: ['AoJ', '딱물', '5']
# 인식한 글자: ['MoJ', '딱물', '기']
# 인식한 글자: ['Aoy', '딱물', '5:']
# 인식한 글자: ['AoJ', '딱물', '>']
# 인식한 글자: ['Aoy', '딱물']
# 인식한 글자: ['Moy', '딱물', '9']
# 인식한 글자: ['Moy', '딱물']
# 인식한 글자: ['Mos', '딱물']
# 인식한 글자: ['AoJ', '딱물']
# 인식한 글자: ['AoJ', '딱물']
# 인식한 글자: ['MoS', '딱물']
# 인식한 글자: ['AoS', '딱물']
# 인식한 글자: ['Aoy', '딱물', '3어']
# 인식한 글자: ['AoJ', '딱물', '과']
# 인식한 글자: ['AoS', '딱물', '5']
# 인식한 글자: ['AoJ', '딱물', '":;', '58']
# 인식한 글자: ['AoJ', '딱물', '벼;', 'R']
# 인식한 글자: ['AoS', '딱물', '58']
# 인식한 글자: ['AoS', '딱물', '58']
# 인식한 글자: ['AoJ', '딱물', '*']
# 인식한 글자: ['AoS', '딱물', '유8']
# 인식한 글자: ['AoS', '딱물', '58']
# 인식한 글자: ['AeS', '딱물', 'h:', 'R8']
# 인식한 글자: ['AoS', '딱물', '7:', '유8']
# 인식한 글자: ['AoS', '딱물', "T'", '유8']
# 인식한 글자: ['AeS', '딱물', '유8']
# 인식한 글자: ['Ae5', '딱물', 'R8']
# 인식한 글자: ['AoS', '딱물', 'R8']
# 인식한 글자: ['AoS', '딱물', '5 8']
# 인식한 글자: ['Ao5', '딱물', '58']
# 인식한 글자: ['AoS', '딱물', '9']
# 인식한 글자: ['Aes', '딱물', 'R8']
# 인식한 글자: ['AeS', '딱물', 'F', '유8']
# 인식한 글자: ['AeS', '딱물', 'F', '유8']
# 인식한 글자: ['Aes', '딱물', '묶8']
# 인식한 글자: ['AoS', '딱물', 'U:?', '98']
# 인식한 글자: ['AeS', "'딱물", '58']
# 인식한 글자: ['Ae', '딱물', '5:']
# 인식한 글자: ['AoS', "'딱물", 'eT8']
# 인식한 글자: ['AoS', "'딱물", '우T8']
# 인식한 글자: ['AoS', '따물', '58']
# 인식한 글자: ['AeS', '딱물', '유다8']
# 인식한 글자: ['AeS', "'딱물", '유']
# 인식한 글자: ['Me5', '딱물', '6성']
# 인식한 글자: ['Wes', '6다성', '딱풀']
# 인식한 글자: ['Wes', '6성', '딱풀']
# 인식한 글자: ['4e5', '딱풀', '::']
# 인식한 글자: ['4eS', '5성', '막풀']
# 인식한 글자: ['MeS', '막풀', '7:']
# 인식한 글자: ['Ms', '딱풀', "'s", '9:']
# 인식한 글자: ['Mes', 'P성', '딱풀']
# 인식한 글자: ['Mes', '과', '딱풀']
# 인식한 글자: ['Mes', '18', '딱풀']
# 인식한 글자: ['M5', '딱물']
# 인식한 글자: ['M;', '딱울']
# 인식한 글자: ['43', '딱풀', '5 ']
# 인식한 글자: ['w3', '딱풀']
# 인식한 글자: ['w3', '딱풀']
# 인식한 글자: ['', 'w5', '딱풀']
# 인식한 글자: ['냐', 'w5', '딱풀']
# 인식한 글자: ['8', 'W3', '따풀']
# 인식한 글자: ['에3', '딱풀']
# 인식한 글자: [')', 'W3', '딱풀']
# 인식한 글자: ['Ws', '5:', '따풀']
# 인식한 글자: ['Wes', '풀', 'P', '4']
# 인식한 글자: ['465', '파풀']
# 인식한 글자: ['W3', '파풀']
# 인식한 글자: ['465', '딱울', "'"]
# 인식한 글자: ['', '46S', '딱풀']
# 인식한 글자: ['', '46S', '딱풀']
# 인식한 글자: ['딴', '풀', '4o3']
# 인식한 글자: ['따풀', 'F', 'wSs']
# 인식한 글자: ['따풀', '5:]', 'wss']
# 인식한 글자: ['ws', '딱풀']
# 인식한 글자: [':', 'w', '딱울']
# 인식한 글자: ['따풀', '2', '4o9']
# 인식한 글자: ['4S', '따풀', '5']
# 인식한 글자: ['4S', '작물']
# 인식한 글자: ['4S', '안', '풀', '5']
# 인식한 글자: ['45', '4', '풀', '93']
# 인식한 글자: ['w:s', '풀', '도', ':']
# 인식한 글자: ['4s', '풀', '도', ':']
# 인식한 글자: ['45', ':', '딱물']
# 인식한 글자: ['45', '풀', '7', '4']
# 인식한 글자: ['45', '4', '7']
# 인식한 글자: ['4N;', '8', '풀', ':']
# 인식한 글자: ['43', 'V', 'I풀']
# 인식한 글자: ['43', '물']
# 인식한 글자: ['43', '풀', '5']
# 인식한 글자: ['43', '파물']
# 인식한 글자: ['4j', '[풀']
# 인식한 글자: ['4', '따물']
# 인식한 글자: ['4j', '따물']
# 인식한 글자: ['A:', '따물']
# 인식한 글자: ['A', '딱물']
# 인식한 글자: ['AS', '따물', '1;']
# 인식한 글자: ['A:S', '딱물']
# 인식한 글자: ['AS', '딱물']
# 인식한 글자: ['4oj', '딱물', '대']
# 인식한 글자: ['4oj', '딱물', '49']
# 인식한 글자: ['4e;', '딱물', '뉴']
# 인식한 글자: ['4oj', 'U', '딱물']
# 인식한 글자: ['4Yo', '딱물', '오']
# 인식한 글자: ['4Ye', '딱물', '9']
# 인식한 글자: ['4YoJ', '딱물', 'O', '4:']
# 인식한 글자: ['4YoJ', '딱물', '뉴']
# 인식한 글자: ['4oJ', '딱물']
# 인식한 글자: ['AYoJ', '딱물', "'6 ;"]
# 인식한 글자: ['딱물', '5', 'NeJ']
# 인식한 글자: ['AeJ', '딱물', '55']
# 인식한 글자: ['AVeJ', '딱물', '5']
# 인식한 글자: ['AoS', '딱물', '1']
# 인식한 글자: ['AoJ', '딱물', '5:']
# 인식한 글자: ['AeJ', '딱물', '5']
# 인식한 글자: ['딱물', '56', 'AMoJ']
# 인식한 글자: ['딱물', '5', 'AMo)']
# 인식한 글자: ['8', 'AMe', '딱물', '5']
# 인식한 글자: ['8', 'AMe', '딱물', '5']
# 인식한 글자: ['AMe', '딱물']
# 인식한 글자: ['AMos', '딱물']
# 인식한 글자: ['4o', '딱물']
# 인식한 글자: ['4o', '딱물']
# 인식한 글자: ['4o', '딱물']
# 인식한 글자: ['Ae', '딱물']
# 인식한 글자: ['4Mo', '딱물']
# 인식한 글자: ['4Vo', '딱물']
# 인식한 글자: ['4Mos', '딱물']
# 인식한 글자: ['S', 'AMoy', '딱물']
# 인식한 글자: ['AVoy', '딱물']
# 인식한 글자: ['AMoy', '딱물']
# 인식한 글자: ['AMo', '딱물']
# 인식한 글자: ['AMo', '딱물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['Ao', '딱물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['Aos', '따물']
# 인식한 글자: ['Aoy', '딱물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['Aos', '딱물', '[']
# 인식한 글자: ['Ao', '따물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['다', 'Aos', '딱물', 'P ']
# 인식한 글자: ['AMos', '딱물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['AoJ', '딱물', '9:']
# 인식한 글자: ['F', 'Aos', '딱물', '구:']
# 인식한 글자: ['(', 'Aos', '딱물']
# 인식한 글자: ['Aos', '딱물', '3이8']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['Aes', '딱물']
# 인식한 글자: ['Aes', "'딱물"]
# 인식한 글자: ['IF', 'Aos', "'딱물"]
# 인식한 글자: ['Ao', "'딱물"]
# 인식한 글자: ['AoS', "'딱물"]
# 인식한 글자: ['AoS', "'딱물"]
# 인식한 글자: ['AoS', '딱물']
# 인식한 글자: ['AoS', "'딱물"]
# 인식한 글자: ['Ao5', '딱물']
# 인식한 글자: ['Ao5', '따물', '우8']
# 인식한 글자: ['Ae5', '딱물']
# 인식한 글자: ['Ao', '딱물']
# 인식한 글자: ['Aes', '따물']
# 인식한 글자: ['Aos', '따물']
# 인식한 글자: ['Aes', '딱물']
# 인식한 글자: ['Aes', '딱물']
# 인식한 글자: ['AoS', '따물']
# 인식한 글자: ['AoS', '따물']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['4os', '딱물', '3']
# 인식한 글자: ['Mes', '따물']
# 인식한 글자: ['Mos', '딱물']
# 인식한 글자: ['Mos', "'딱물", '98']
# 인식한 글자: ['Ao5', '딱물', '48']
# 인식한 글자: ['Ae5', '딱물', '58']
# 인식한 글자: ['Ao5', '딱물', '우다8']
# 인식한 글자: ['Ae5', '딱물']
# 인식한 글자: ['Ae5', "'딱물"]
# 인식한 글자: ['AoS', "'딱물", '우8']
# 인식한 글자: ['AoS', "'딱물", '우8']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['4473', '띄물']
# 인식한 글자: ['43']
# 인식한 글자: ['딱물', '4 ']
# 인식한 글자: ['Aaj', '756', '딱물']
# 인식한 글자: ['Aj', '딱물', '우다:']
# 인식한 글자: ['Aoj', '딱물', '5']
# 인식한 글자: ['Aoj', '딱물', '유']
# 인식한 글자: ['Aoj', '딱물', '5']
# 인식한 글자: ['Aoj', '딱물', '5']
# 인식한 글자: ['Ao', '딱물', '5']
# 인식한 글자: ['Aoj', '딱물', '5K']
# 인식한 글자: ['Aoj', '딱물', '(']
# 인식한 글자: ['AoJ', '딱물', '두']
# 인식한 글자: ['Ja', 'Aoj', '딱물', '우K']
# 인식한 글자: ['%', 'Aoj', '딱물', '5']
# 인식한 글자: ['해', 'Aoj', '딱물', '5']
# 인식한 글자: ['어', 'Aoj', '딱물', '5']
# 인식한 글자: ['Jn', '딱물', '5', 'AMo']
# 인식한 글자: ['꺼n', 'Aoj', '딱물', '5']
# 인식한 글자: ['꺼n', '딱물', 'P', 'AMo']
# 인식한 글자: ['꺼n', '딱물', '5L', 'AMoJ']
# 인식한 글자: ['an', 'Moj', '따물', '5']
# 인식한 글자: ['an', 'Moj', '딱물', '5']
# 인식한 글자: ['Aoj', '.n', '따물', '5L']
# 인식한 글자: ['AMoj', 'anl', '따물', 'F']
# 인식한 글자: ['Aoj', 'an', '딱물', '5E']
# 인식한 글자: ['AMoj', '딱물', '"X', '묘', 'aanj']
# 인식한 글자: ['Ao}', '딱물', '무t ', '모78', 'Jans']
# 인식한 글자: ['Aoj', '딱물', '모', 'Jans']
# 인식한 글자: ['Aoj', '딱물', '모7:', 'an']
# 인식한 글자: ['anj', '딱물', '유시', 'Wos']
# 인식한 글자: ['AMoJ', 'an', "'딱물", 'XX', '유시']
# 인식한 글자: ['AoJ', 'ani', '딱물', '두I:']
# 인식한 글자: ['MOY', '[딱풀', '닦8', 'aan`']
# 인식한 글자: ['MOY', '[딱풀', '닦', 'aan`']
# 인식한 글자: ['}', '유:', 'Jani', '막물']
# 인식한 글자: ['엽T하이', '[딱물', '무', 'Jans']
# 인식한 글자: ['엽Td구', 'ani', '묘:', '딱물']
# 인식한 글자: ['V엽Tda', 'ani', '딱물', '무']
# 인식한 글자: ['동', '@n', '[딱물', '무']
# 인식한 글자: ['건일학다', 'an', '[딱물', '무']
# 인식한 글자: ['oaVaaai다', '.n', '[딱물', '유껑']
# 인식한 글자: ['Vl', '.n', '유', '딱풀']
# 인식한 글자: ['쑤n', '[딱물', '유성']
# 인식한 글자: ['.n', '[딱물', ' 성']
# 인식한 글자: ['w ', 'a', '냐:', '딱물']
# 인식한 글자: ['w ', 'a', '냐:', '딱물']
# 인식한 글자: ['AVJ', 'ai', '8', '딱풀']
# 인식한 글자: ['AVJ', 'ani', '우요:', '딱풀']
# 인식한 글자: ['MVJ', 'Ging', '우드:', '딱물']
# 인식한 글자: ['Aos', 'Gins', '유성', '딱물']
# 인식한 글자: ['ing', '따물', '유성', 'Aos']
# 인식한 글자: ['Mos', 'Jins', '따물', '유다:']
# 인식한 글자: ['Mos', 'Ging', '따물', '유다:']
# 인식한 글자: ['MoS', 'jan`', '따물', '우생']
# 인식한 글자: ['MoS', 'an', '따물', '유:']
# 인식한 글자: ['Ao5', 'anj', '딱물', '묘8']
# 인식한 글자: ['ANoS', '@n', '딱물', '유8']
# 인식한 글자: ['ANoS', '@n', '딱물', '유']
# 인식한 글자: ['', 'Ao5', 'Jni', '딱물', '유성']
# 인식한 글자: ['고녁', 'Ao5', '.ni', '딱물', '유8']
# 인식한 글자: ['a다', 'an', 'MoS', '딱물', '묘']
# 인식한 글자: ['R', 'anl', 'Ao5', '딱물', '유8']
# 인식한 글자: ['an', 'Ao5', '딱물', '유8']
# 인식한 글자: ['an', 'AoS', '딱물', 'ti', '5']
# 인식한 글자: ['세', 'ani', 'AoS', '딱물', 'N', '유8']
# 인식한 글자: ['ani', 'AoS', '딱물', '톤8']
# 인식한 글자: ['Gn', 'Ae', '따물', '58']
# 인식한 글자: ['anl', 'AeS', '따물', '톤8']
# 인식한 글자: ['8n', 'Ao5', '따물', '5V8']
# 인식한 글자: ['8n', 'Ao5', '따물', '5V8']
# 인식한 글자: ['.n', 'AeS', '따물', '우48']
# 인식한 글자: ['.n', 'Ae5', '딱풀']
# 인식한 글자: ['꺼n', 'Mes', "'따물"]
# 인식한 글자: ['Jn', 'MeS', "'따물"]
# 인식한 글자: ['Jn', 'AeS', "'따물"]
# 인식한 글자: ['Jn', 'MoS', "'따물"]
# 인식한 글자: ['J', 'AeS', "'따물"]
# 인식한 글자: ['Ja', 'Ae5', '98', '딱풀']
# 인식한 글자: ['J', '4e5', '딱풀']
# 인식한 글자: ['이', '4e5', '5:', '딱풀']
# 인식한 글자: ['4e5', '딱풀', '우58']
# 인식한 글자: ['4e5', '딱풀', '4:']
# 인식한 글자: ['4eS', '딱풀', '우8']
# 인식한 글자: ['AeS', '따물', 't', '4:']
# 인식한 글자: ['Aes', '따풀', '우8']
# 인식한 글자: ['Aes', '딱풀']
# 인식한 글자: ['4s', '풀', '딱']
# 인식한 글자: ['Mes', '딱풀']
# 인식한 글자: ['4es', '딱물', '4']
# 인식한 글자: ['4es', '따물', '48']
# 인식한 글자: ['4es', '따물']
# 인식한 글자: ['Mes', '따물']
# 인식한 글자: ['4e5', '따물', '(8']
# 인식한 글자: ['4e5', '따물', '(8']
# 인식한 글자: ['4es', '딱물', 'rt']
# 인식한 글자: ['Mes', "t'", '딱울']
# 인식한 글자: ['4es', '딱물', 'e;']
# 인식한 글자: ['다', 'AMes', '딱풀', '2n']
# 인식한 글자: ['AMes', '딱물', 'U:']
# 인식한 글자: ['AMeS', '딱물', "'"]
# 인식한 글자: ['MeS', '딱물', '*7']
# 인식한 글자: ['Uos', '따물', 'Ur']
# 인식한 글자: ['vas', '따물', '*77']
# 인식한 글자: ['WNS', '딱풀', '~']
# 인식한 글자: ['ANUS', '딱물', 'K']
# 인식한 글자: ['ANUS', '딱물', 'K']
# 인식한 글자: ['4Aos', '따풀', '2']
# 인식한 글자: ['Aos', '파물', 'TNr']
# 인식한 글자: ['4os', '따물', 'PU;']
# 인식한 글자: ['4os', '딱풀', 'C;']
# 인식한 글자: ['4os', '파물']
# 인식한 글자: ['AoS', '따물', 'W']
# 인식한 글자: ['4os', '딱풀', '2']
# 인식한 글자: ['4os', '풀', '9']
# 인식한 글자: ['4os', '딱물', 'Yon']
# 인식한 글자: ['4os', '풀', '4']
# 인식한 글자: ['4os', '풀', '4']
# 인식한 글자: ['4os', '풀', '4']
# 인식한 글자: ['4os', '따물', '{']
# 인식한 글자: ['4os', '따물', '{']
# 인식한 글자: ['4os', '딱물']
# 인식한 글자: ['4os', '딱물']
# 인식한 글자: ['4os', '딱물']
# 인식한 글자: ['Ao', '딱물']
# 인식한 글자: ['4os', '딱물', '2n']
# 인식한 글자: ['AMos', '딱물']
# 인식한 글자: ['4os', '딱물']
# 인식한 글자: ['4Mos', '딱물']
# 인식한 글자: ['AMos', '딱풀']
# 인식한 글자: ['AMos', '딱풀']
# 인식한 글자: ['AMos', '따물', "'"]
# 인식한 글자: ['AMos', '따물', 'V']
# 인식한 글자: ['Aos', '딱풀']
# 인식한 글자: ['AMoy', '딱물', "(a'"]
# 인식한 글자: ['Aos', '딱물', '2']
# 인식한 글자: ['Aos', '딱풀', 'Yt;']
# 인식한 글자: ['Mos', '딱물', 'Ctr]']
# 인식한 글자: ['Ao', '딱물', '(tr']
# 인식한 글자: ['Aos', '딱물']
# 인식한 글자: ['Mos', '딱풀', '(']
# 비디오 종료
# Mean score of BLEU: 0.12356979405034325, Total Frame: 437

# %% [markdown]
# ## 실험결과 정리
#
# |품목 이름|평균 BLEU 스코어|프레임 수|
# |---|---|---|
# |Cetaphil|0.295|325|
# |만능크리너|0.88|443|
# |정관장|0.48|434|
