# %%
import easyocr

# %%
# import the opencv library
import cv2

reader = easyocr.Reader(['ko','en'], gpu=True)

# define a video capture object
vid = cv2.VideoCapture(0)
  
while(True):
      
    # Capture the video frame
    # by frame
    ret, frame = vid.read()
    result = reader.readtext(frame, batch_size=32, detail=0)
    print(result)
  
    # Display the resulting frame
    cv2.imshow('frame', frame)
      
    # the 'q' button is set as the
    # quitting button you may use any
    # desired button of your choice
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
  
# After the loop release the cap object
vid.release()
# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# []
# []
# ['C']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['=다']
# ['글다']
# ['다']
# ['{']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Pow']
# ['6T세', 'Pol']
# ['Pok']
# ['OT']
# []
# []
# []
# []
# []
# []
# ['4NN', '다']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['겉']
# ['C']
# ['d이1', '각|다']
# ['전이']
# ['벗이']
# ['이', "'N", '팀세시 +']
# ['(기', '세V', '쓰다']
# ["'것이", "'", '데스트다', '팀', '비"']
# ['(것이', '취업음 위한', '테스트다', '당', '이씬']
# ['(것이', "'시 MI", '데스트르다', '딩', 'Iw']
# ['(것이', "'시 MI", '데스트르다', '딩', 'Iw']
# ['미것이', '시; 위산', "'딩", '테스트다', 'ILoln']
# ['검진에서', '이것이', '왼스', '취업률 위산', "'딩", '테스트다', '파oM']
# ['검진에서', '이것이', '왼스', "'불", '진업률 위한', '딩', '테스트다', 'TLol']
# ['컴진에서', '이것이', '왼스', '취업: 위한', '팅', '테스트다', '']
# ['컴진에서', '이것이', '왼스', '취엽률 위한', '고딩', '테스르다', 'IIun']
# ['컴진에서', '이것이', '흰스', '쥐업: 위한', '고딩', '테스타다', 'l']
# ['컴진에서', '이것이', '왼스{', '7', '업률 위한', '{딩', '테스트다', 'T']
# ['검진에서', '이것이', '왼스', '취엽올 위한', '당 테스_']
# ['검진에서', '미것이', '왼스다', "'", '취업률 위한', '당 테스_']
# ['컴진에서', '이것이', '왼스', "'", '쥐업올 위한', '당 테스_']
# ['컴진에서', '이것이', 'S', '취업률 위한', '당 테스_']
# ['컴진에서', '이것이', '왼스', '취업률 위한', '당 테스_']
# ['검진에서', '이것이', '왼스', '취업: 위찬', '당 테스_']
# ['컴진에서', '이것이', '왼스', '2', '취업울 위한', '당 테스_']
# ['검진에서', '이것이', '왼스', '취업올 위한', '딩 테스-']
# ['컴진에서', '이것이', '왼스', '취업울 위한', '당테스-']
# ['컴진에서', '이것이', '왼스', '취업률 위한', '당 테스-']
# ['검진에서', '이것이', '왼스', '취업슬 위한', '당테사)']
# ['컴진에서', '미것이', '왼스다', "'", '취업률 위한', '당 테스)']
# ['검진에서', '이것이', '흰스', '취업올 위한', '당테사)']
# ['컴진에서', '이것이', '왼스', '쥐업을 위한', '당테M")']
# ['검진에서', '이것이', '왼스', '취업을 위한', '딩', '테스']
# ['#인파무성(', '컴진에서', '이것이', '왼스', '취업올 위한', '딩 테사']
# ['검진에서', '이것이', '왼스', '취업음 위한', '당 테스-']
# ['검진에서', '이것이', '왼스', '취업음 위한', '딩 테M"']
# ['{인디무성청', '컴진에서', '미것이', '왼스다', "'", '취업음 위한', '팅 테M"']
# ['기것이', '"\'서', '취 위한', '딩테사']
# ['(것이', '취업 위한', '디대']
# ["'마시", '컴리에서', '(것이', '취업울 위한', '디 대 ']
# ['아사', '(것이', '취업 위한', '디 대']
# ["'마시", '기것이', '컴진에서', '7', '취업음 위한', '닿', 'I7 _']
# ['이것이', '크팅', "'% 위기", 'h']
# ['이것이', '규다', '<N: ,t']
# ['이것이', 'J다', '시요 암다 `']
# ['이것이', '', '최녀스', '6 그']
# ['이것이', '컴퓨에서', '5', '기어 6']
# ['이것이', '컴진에?']
# ['이거 ~']
# ['이거 ']
# ['0/>I']
# ['0/J4']
# ['OIJI `']
# ['0/J']
# ['0/>I']
# ['0/JI']
# ['0/JI']
# ['0/>I']
# ["0/>'"]
# ['O/JI`']
# ['0/JI']
# ["OI-'"]
# ['O/JI']
# ['0/J']
# ['OIJ `']
# ['0/J ']
# ['OI-']
# ['OIJ']
# ['OIS']
# ['OJ']
# ['O/J `']
# ['OIJI`']
# ['이거 ']
# ['이것이', '~사하다', '수무다']
# ['이것이', '취 위사', '긁다 ']
# ['이것이', '쥐갑; 미시', '고딩', '테스 -']
# ["'메인미주", "'검진에'", '이것이', '취업음 위한', '코딩', '테스= 동']
# ['처리에', '이것이', '취업음 위한', '코딩', '테스트F다']
# ['대인피구', '검진에', '이것이', '취업음 위찬', '코딩', '테스트다', 't ag']
# ["'메인피루", "'컴리어", '이것이', '취업음 위한', '코딩', '테스트다', 'wirhruu']
# ['어인피부', '컴진이', '이것이', '취업음 위한', '코딩', '테스트다', 'with 파oM']
# ['이것이', '취 7a', '코딩', '테스트대', '파이씬', 'WIUIi']
# ['이것이', '위찬', '쉬울', '코딩', '테스트대', 'with 파이씬']
# ['검진다', '이것이', '쥐음 위한', '코딩', '테스트다', 'with 파이씬']
# ['검진이', '이것이', '쥐업음 위하', '코딩', '테스트대', 'with 파이씬']
# ['검진야', '이것이', '쥐업음 위찬', '코딩', '테스트다', 'with 파이씬']
# ['어인미h', "'검진이", '이것이', '쥐업음 위찬', '코딩', '테스트대', '파이씬', 'with']
# ["'검진9", '이것이', '쥐음 위찬', '코딩', '테스트대', 'with 파이씬']
# ["'인쇄;", '검진', '이것이', '쥐업음 위한', '코딩', '테스트대', 'with 파이씬']
# ["'인미부", '검진9', '이것이', '쥐음 위찬', '코딩', '테스트다', '파이씬', 'with']
# ["'인따터", '검잖9', '이것이', '쥐음 위한', '코딩', '테스트대', '파이씬', 'withi']
# ["'대인미부성", '검진', '이것이', '쥐업음 위반', '코딩', '테스트대', 'with 파이씬']
# ['어인미부', '검진', '이것이', '쥐업음 위한', '코딩', '테스트대', 'with 파이씬']
# ["'대인미부-성일", '검진9', '이것이', '쥐업음 위반', '코딩', '테스트대', 'with 파이씬']
# ["'어인미구성청", '검진', '이것이', '쉬업음 위한', '코딩', '테스트대', 'with 파이씬']
# ['N인미부 성인', '검진', '이것이', '쥐업음 위찬', '코딩', '테스트디', 'with 파이씬']
# ["'어인미'", '검진', '이것이', '쥐업음 위한', '코딩', '테스트다', 'with 파이씬']
# ['어인미부', '검진', '이것이', '쥐I음 위한', '코딩', '테스트디', 'with 파이씬']
# ["'어인미부성", '검진', '이것이', '쥐음 위한', '코딩', '테스트디', 'with 파이씬']
# ["'대인미부 성험", '천진', '이것이', '쥐업음 위한', '코딩', '테스트디', 'with 파이씬']
# ["'인미다", ' 진', '이것이', '쥐업음 위한', '코딩', '테스트대', '파이씬', 'with']
# ["'인미'", "'검진이", '이것이', '쥐업음 위한', '코딩', '테스트다', 'with 파이씬']
# ["검진이'", '이것이', '쥐업음 위찬 `', '코딩', '테스트다', 'with 파이씬']
# ['이것이', '코딩 테스트다', '바아w', 'Wto']
# ['이것이', '코딩 테스트다', 'with 파이씬']
# ['이것이', '위한', '취업음', '코딩 테스트다', 'with 파이씬']
# ["'다서", '이것이', '위한', '취업음', '고딩 테스트다', 'vith 파이씬']
# ["'", '이것이', '위친', '취언음', '코딩 테스트다', 'with 파이씬']
# ['이것이', '위i', '코딩 테스트다', 'withi 파이씬']
# ['이것이', '쉬다: 주찬 `', '코딩', '테스트다', 'with 파이씬']
# ['이것이', "쉬'울 위한", '코딩', '테스트다', '파이씬', 'with']
# ['검진어', '이것이', '쉬업음 위한', '코딩', '테스트다', 'with 파이씬']
# ["'검진'", '이것이', '취업음 위한', '코딩', '테스트대', 'with', '파이씬']
# ['어인미터;', 's{', '이것이', '취업음 위한', '코딩', '테스트디', 'with', '파이씬']
# ["'대인피주", '이것이', '쥐업음 위찬', '코딩', '테스트디', '파이씬', 'with']
# ["'대인피무;", '이것이', '쥐업음 위한', '코팅', '테스트디', 'with', '파이씬']
# ["'대인피부성", '이것이', '취업음 위한', '코딩', '테스트디', 'with 파이씬']
# ["'대인피구성", '이것이', '쥐업음 위한', '코딩', '테스트디', 'with', '파이씬']
# ["'너인피무성", '이것이', '취업음 위한', '코딩', '테스트디', 'with 파이씬']
# ["'어인미구성산", '이것이', '쥐업음 위한', '코딩', '테스트디', 'with', '파이씬']
# ["'예인피부성", '이것이', '쥐업음 위한', '코딩', '테스트디', 'with', '파이씬']
# ["'대인미무성", '이것이', '쥐업음 위한', '코딩', '테스트디', 'with', '파이씬']
# ['여인피구성청', '이것이', '쥐업음 위한', '코딩', '테스트디', 'with', '파이씬']
# ["'예인피부", 'y순', '이것이', '위한', '쥐업음', '코딩', '테스트디', 'with', '파이씬']
# ['이것이', '취업음 위한', '코팅', '테스트디', 'with', '파이씬']
# ["'예인미부", '이것이', '쥐업음 위한', '코딩', '테스트디', 'with', '파이씬']
# ['어인피무;', '이것이', '쥐업음 위한', '코딩', '테스트디', 'with', '파이씬']
# ['세인피다', '이것이', '취업음 위한', '코팅', '테스트디', '파이씬', 'with']
# ['사인미부성', '이것이', '쥐업음 위한', '코딩', '테스트디', 'with', '파이씬']
# ['여인미구 성애', '검진', '이것이', '쥐업음 위한', '코팅', '테스트디', 'with', '파이씬']
# ['이것이', '코딩', '테스트다', 'a {']
# ['기것이', '그딩 데스트다', '"1 베이씨']
# ['기것이', '위하', '취업음', '고딩 테스트다', 'ith 파이씬']
# ['기것이', '위한', '취업음', '고딩 테스트다', "'ith 파이씬"]
# ['재인', '이것이', '위한', '취업음', '고딩 테스트다', 'with 파이씨']
# ['이것이', '위찬', '취업음', '코딩 테스트다', 'with 파이씬']
# ['이것이', '테스트다', '코딩', 'Itli 빠이씨']
# ['이것이', 'f블 뒤친 `', '코딩', '테스트대', '파이씬', 'with']
# ['이것이', '취% 뒤사', '코딩', '테시=다', 'Win', 'w망ee']
# ['메인피무성', '이것이', '코딩', '취업음 위한', '테스 _', 'V;']
# ['이것이', '코딩', '테스트다']
# ['이것이', '코딩 테스트다', 'with 파이씬']
# ['이것이', '코딩 테스트다', 'Mith 파이변']
# ['기것이', '고딩 테스트다', '파이씬', 'ith']
# ['것이', '당 테스트다', '싸이씨']
# ['h입다', '위하', '것이', '취업올', '팅 테스트다', '바이씬']
# ['것이', '위한', '취업음', '칭테스트다', '[이씬']
# ['처이', '시 `', '상 테스트다', '[이씬']
# ['I것이', '그딩 테스트다', 'NS']
# ['이것이', '고딩 테스트다']
# ['이것이', "튿'", '~']
# ['이것이', '스른으 ', '다', '#']
# ['이것이', '차1으', '의구']
# ['이것이', '최언l 위']
# ['이것이', '취업유']
# ['이것이', '시 수', 'G']
# ['이것이', "코디 3' -"]
# ['이것이', '위한', '취업음', '코디 테스=']
# ['UU미', '이것이', '취음 우리', '코딩 테스트']
# ['이것이', '취소 위', '고딩 테스트', '8_c어']
# ["'메인미부 성y", '이것이', '위', '취업음', '코딩 테스트', 'with 파이내']
# ['이것이', '코딩 테스트']
# ['이것이', '코형 테스트다', '사-소 그이번']
# ['이것이', '테스트다', '고딩', '파아뻔']
# ['위진', '취업음', '것이', '테스트다', '당', '파이씬']
# ['주?! 구찬', '것이', '테스트다', '팅', '나이씬']
# ['위찬', '취업음', '보이', '테스트다', '팀', '[이번']
# ['{', '이', '테스트다']
# ['위한', '이', '취업음 ', '테스트다']
# ['위찬', '이', '취업음', '테스트다', "'", '씬']
# ['구한', '취섭음', '보이', '테스트다', '팅', '가이씬']
# ['위', '쥐터물 .', '것이', '팅 테스트다', "'파이씬"]
# ['위찬', '취업음', '(것이', '테스트다', '딩', '파이씬', 'th']
# ['위반', '[것이', '취업음', '테스트다', '크딩', '파이씬', 'ith']
# ['대인', '위하', '기것이', '취업음', '{중 테스트다', '파이씬', 'jith']
# ['US다', '위하', '취업음', '이것이', '고정 테스트다', "'파이씬", 'vith']
# ['위한', '기것이', '취업음', '코정 테스트다', '파이씬', 'with']
# ['이것이', '으', '톤음', '코정 테스트다', 'with 파이씬']
# ['이것이', '으불', '스름', '코령 테스트다', 'with 파이씬']
# ['이것이', '우한', '주름름', '코랑 테스트디', 'with 파이씬']
# ['이것이', '위응', '스근음', '코팅 테스트다', 'with 짜이씬']
# ['이것이', '으', '스들', '코딩 테스트', 'wlth 파이생']
# ['에인피', '이것이', '위히', '취업음', '코딩 테스트', 'wItli 파이씬']
# ['이것이', '위깔', '취업음', '코딩 테스트', 'wth 파이씬']
# ['이것이', '위', '취업음', '고딩 테스트', 'with 파이씬']
# ['이것이', '위', '취업음', '고딩 테스트', 'with 파이씬']
# ['이것이', '위려', '취업음', '고딩 테스트', 'wlth 파이씬']
# ['이것이', '위히', '취업음', '코딩 테스트', 'with 파이씬']
# ['이것이', '위한', '취업음', '코딩 테스트', 'with 파이씨']
# ['이것이', '위한', '취업음', '코딩 테스트', 'wItIi 끼이씨']
# ['이것이', '위한', '취업음', '코딩 테스트', 'with 파이씬']
# ['이것이', '위한', '취업음', '코딩 테스트', 'witli 짜이씬']
# ['이것이', '위한', '취업음', '고딩 테스트', 'with 파이씬']
# ['이것이', '위한', '취업음', '코딩 테스트', 'wlth 짜이씬']
# ['대인', '이것이', '위한', '취업음', '고딩 테스트', 'with 파이씬']
# ['이것이', '위한', '취업음', '고딩 테스트', 'with 파이씬']
# ['이것이', '위한', '취업음', '코딩 테스트', 'with 파이씬']
# ["'대인파", '위하', '이것이', '취업음', '고딩 테스트', 'with 파이씬']
# ["'예인피", '이것이', '위히', '취업', '코딩 테스트', 'with 파이씬']
# ["'메인피터", '이것이', '위히', '취업음', '고딩 테스트', 'with 파이씬']
# ['이것이', '위', '취험울', '코딩 테스트', 'with 파이씬']
# ['이것이', '드', '취업음', '코딩 테스레', 'with 파이씬']
# ['이것이', '쥐업음', '코딩 테스', 'with 파이씬']
# ['이것이', '작심', '코딩 테스', 'with 파이씬']
# ['이것이', '코딩 테스', 'with 파이씬']
# ['이것이', '코딩 테_', 'wiIth 파이번']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 터', 'with 파이씬']
# ['이없이', '코딩 터', 'with 파이씬']
# ['이고이', '코딩 터', 'with 파이씬']
# ['이[이', '코딩 E', 'with 파이씬']
# ['흩기', '코딩', 'E', 'with 파이씬']
# ['x-', '코딩 E', 'with 파이']
# ['I- 다', '코딩 터', 'with 파이씬']
# ['81x- |', '코딩 터', 'with 파이씬']
# ['Lx- L', '코딩 터', 'with 파이씬']
# ['(Ir- 다', '코딩 터', 'with 파이씬']
# ['~r- I', '코딩 E', 'with 파이씬']
# ['- 다', '코딩 E', 'with 파이씬']
# ['(| r-', '코딩 E', 'with 파이씬']
# ['브x-', '코딩 E', 'with 파이씬']
# ['Ir기', '코딩 E', 'with 파이씬']
# ['에x흩기', '코딩 E', 'with 파이씬']
# ['Ixc기', '코딩 E', 'with 파이씬']
# ['기', '코딩 E', 'with 파이씬']
# ['<-', '코딩', 'E', 'with 파이씬']
# ['<Vr ', '코딩', 'E', 'with 파이씬']
# ['UIr기', '코딩 E', 'with 파이씬']
# ['이r이', '코딩 터', 'with 파이씬']
# ['이것이', '코딩 터', 'with 파이씬']
# ['이r이', '코딩 터', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이r이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이 ', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이솟이', '코딩 테', 'with 파이']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것r이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이)이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이고이 (', '코딩 테', 'with 파이씬']
# ['이고이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이고이', '코딩 테', 'with 파이씬']
# ['이고이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이고이', '코딩 테', 'with 파이씬']
# ['이고이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이r이', '코딩 테', 'with 파이씬']
# ['이r이', '코딩 테', 'with 파이씬']
# ['이고이 (', '코딩 터', 'with 파이씬']
# ['이고이 (', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이고이', '고딩 테', 'with 파이씬']
# ['이고이', '고딩 테', 'with 파이씬']
# ['이고이', '코딩 테', 'with 파이씬']
# ['이것이', '고딩 테', 'with 파이씬']
# ['이고이', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이것이', '(', '코딩 테', 'with 파이씬']
# ['이것이', '코딩 테', 'with 파이씬']
# ['이고이', '코딩 테스', 'with 파이씬']
# ['이r이', '코딩 테스', 'with 파이씬']
# ['제다하다', '코딩 테스', "wIII' 씨에w"]
# ['코딩', '레스', 'with 파이씬']
# ['( ? )', 'rith 파이씬', '선_논', 'Irr', '위이', '~거리']
# ['무 (?)', 'rith 파이씬', '선?', 'JTYi업', '위끝이', '부거리']
# ['2 ( <', 'vith 파이씬', '선_노', 'JTi', '쥐)이', '~거리']
# ['1곰 (? )', 'with 파이씬', '신_람', '쥐물91', 'ITi', " > 거기'"]
# ['그- ~', 'with 파이씬', '씨U*', 'Jti']
# ['T', 'a', 'with 파이씬', '샌_논', 'ri', '쉬)이']
# ['T', '우', 'with 파이씬', '선_논', '쉬3)이', 'JTYi']
# ['T', '우이', 'with 파이씬', '선_노', 'JtYi', '쉬3이']
# ['이', "'a -", 'with 파이씬', '선_람', 'JTi', '쥐39']
# ['(', "'a스다", 'with 파이씬', '선_노', 'ITi', '쉬3이']
# ['IT', 'P -', 'with 파이씬', '선_람', 'ITVi', '쉬3이']
# ['IT', '그다다', 'with 파이씬', '선_논', 'ITYi', '쉬3 이']
# ['T', '빌다', 'with 파이', '선_노', 'rn', '쥐39']
# [' C', '무', 'with 파이씬', '선화난', 'IrYi', '쉬9']
# [' C', '다', 'with 파이씬', '선_논', 'ITYi', '쉬로9']
# [' T', '나그', 'with 파이씬', '선_노', 'rrVn', '쉬39']
# [' C', '다 -', 'with 파이씬', '선화논', '쥐391', 'ITi']
# [' C', "'a그", 'with 파이씬', '선사논', '쉬39', 'JY']
# [' (', "'그", 'with 파이씬', '선_', 'JrYn', '쉬39']
# [' (', "'그", 'with 파이씬', '선화논', '쉬391', 'IYi']
# [' C', "'a기", 'with 파이씬', '선화논', '쥐39', 'ITYi']
# [' C', '나ar', 'with 파이씬', '선화논', 'ITYi', '위39']
# [' C', '우다기', 'with 파이씬', '선화논', 'ITi', '쉬로9']
# ['9', "'a", 'with 파이씬', '선바논', '쉬39', 'ITi']
# ['I이', '그배', 'with 파이씬', '선화논', 'ITi', '쉬둥이']
# ['이', "'a", 'with 파이씬', '선화논', '쉬로 9', 'ITi']
# ['이', '그다', 'with 파이씬', '선_논', 'ITi업', '쉬물 9']
# ['T', "'a", 'with 파이씬', '선화논', '쥐391', 'IrYi']
# ['IT', '우다', 'with 파이씬', '선화논', 'A물9', 'ITYi']
# ['T', 'a', 'with 파이씬', '선화논', 'A물9', 'ITi']
# ['T', '이기', 'with 파이씬', '선_논', 'ITi', '쉬물이']
# [' C', "'m다", 'with 파이씬', '선화논', 'ITYi', '쉬39']
# ['T', "'무다기", 'with 파이씬', '선_논', 'A91', 'rVi']
# ['고문9', 'witli 빠이m', 'MY', '2I', '~V서']
# ['코K U', "NV' Wiw"]
# ['코딩 테스', 'WItli 빠이씨']
# ['하다무', '코딩 테스', 'witli 싸이w']
# ["'l극7니", '고딩 테스', 'with 파이씬']
# ["' 극7`니", '코딩 테스', 'with 파이씬']
# ["'l k7", '고딩 테스', 'with 파이씬']
# ["'니 극7", '코딩 테스', 'with 파이씬']
# ["' 5-", '고딩 테스', 'with 파이씬']
# ['|', '고딩 테스', 'with 파이씬']
# ['코딩 테스', 'with 파이씬']
# ['|', '코딩 테스', 'with 파이씬']
# ['코딩 테스', 'with 파이씬']
# ['고딩 테스', 'with 파이씬']
# ['코딩 테스', 'with 파이씬']
# ['고딩 테스', 'with 파이씬']
# ['코딩 테스', 'with 파이씬']
# ['코딩 테스', 'with 파이씬']
# ['코딩 테스', 'with 파이씬']
# ['코딩 테스', 'with 파이씬']
# ['코딩 테스', 'with 파이씬']
# ["'", 'n_', '코딩 테스', 'with 파이씬']
# ['이틀이', '고딩 테스', 'with 파이씬']
# ['이것이', '취신', '고딩 테스', 'with 파이씬']
# ['이것이', '취십', '고딩 테스', 'wlth 파이씬']
# ['이것이', '쥐', '코딩 테스', 'with 파이써']
# ['이것이', '쥐', '고딩 테스', 'with 파이뻐']
# ['이것이', '쥐', '코딩 테스', 'with 파이씬']
# ['이것이', '코딩 테스', 'with 파이씬']
# ['이것이', '코딩 테스', 'with 파이씬']
# ['이것이', '코딩 테스', 'with 파이씬']
# ['이것이', '고딩 테스', 'with 파이뻐']
# ['이것이', '고딩 테스', 'with 파이씬']
# ['이것이', '고딩 테스', 'with 파이씬']
# ['이것이', '첫', '고딩 테스', 'with 파이씬']
# ['이것이', '고딩 테스', 'with 파이씬']
# ['이것이', '취', '코딩 테스', 'with 파이씬']
# ['이것이', '쥐', '코딩 테)', 'with 파이씬']
# ['이것이', '쥐', '코딩 테스', 'with 파이씬']
# ['이것이', '쥐', '코딩 테)', 'with 파이씬']
# ['이것이', '쥐', '코딩 테스', 'with 파이씬']
# ['이것이', '쥐', '코딩 테스', 'with 파이뻐']
# ['이것이', '취', '코딩 테)', 'with 파이씬']
# ['이것이', '쥐', '코딩 테스', 'with 파이씬']
# ['이것이', '코딩 테)', 'with 파이씬']
# ['이것이', '쥐', '코딩 테스', 'with 파이씬']
# ['이것이', '고딩 테스', 'with 파이씬']
# ['이것이', '코딩 테스', 'with 파이']
# ['이것이', '코딩 테스', 'with 파이씬']
# ['이것이', '쥐', '코딩 테스', 'with 파이씬']
# ['이것이', '쥐', '코딩 테스', 'with 파이씬']
# ['이것이', '쥐', '코딩 테)', 'with 파이씬']
# ['이것이', '코딩 테스', 'with 파이씬']
# ['이것이', '쥐', '코딩 테)', 'with 파이씬']
# ['이것이', '쥐', '코딩 테스', 'with 파이씬']
# ['이것이', '쥐', '코딩 테)', 'with 파이씬']
# ['이것이', '코딩 테스', 'with 파이씬']
# ['이슷이', '쥐', '코딩 테)', 'with 파이씬']
# ['이것이', '코딩 테)', 'with 파이씬']
# ['이)이', '코딩 테_', 'with 파이씬']
# ['이r이', '코딩 테_', 'with 파이씬']
# ['이r이', '코딩 테_', 'with 파이씬']
# ['이x이', '주', '코딩 테_', 'with 파이씬']
# ['?', '이r이', '코딩 테', 'with 파이씬']
# ['7', '이r이', '코딩 테', 'with 파이씬']
# ["'", '이r이', '코딩 테', 'with 파이씬']
# ['이X이', '고딩 테', 'with 파이씬']
# ['e1극 `', '코딩 테', 'with 파이씬']
# ['[ - 7다 `', '코딩 테', 'with 파이씬']
# ['코딩 터', 'with 파이씬']
# ['고딩 터', 'with 파이씬']
# ['코딩 터', 'with 파이씬']
# ['코딩 터', 'wthi 마이w']
# ['%스<^', '코딩 [', 'with 파이씬']
# ['% `', '코딩 .', 'with 파이씬']
# ['코딩', 'with 파이신']
# ['코딩', 'wIth 까이:']
# [' -', 'with 파이']
# [' -', '2', 'with 파이=']
# ['with 파이쓰']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\HOJUN_~1\AppData\Local\Temp/ipykernel_29212/2372597303.py in <module>
#      12     # by frame
#      13     ret, frame = vid.read()
# ---> 14     result = reader.readtext(frame, batch_size=32, detail=0)
#      15     print(result)
#      16
#
# c:\Users\hojun_window\anaconda3\envs\yolov5\lib\site-packages\easyocr\easyocr.py in readtext(self, image, decoder, beamWidth, batch_size, workers, allowlist, blocklist, detail, rotation_info, paragraph, min_size, contrast_ths, adjust_contrast, filter_ths, text_threshold, low_text, link_threshold, canvas_size, mag_ratio, slope_ths, ycenter_ths, height_ths, width_ths, y_ths, x_ths, add_margin, output_format)
#     383         img, img_cv_grey = reformat_input(image)
#     384
# --> 385         horizontal_list, free_list = self.detect(img, min_size, text_threshold,\
#     386                                                  low_text, link_threshold,\
#     387                                                  canvas_size, mag_ratio,\
#
# c:\Users\hojun_window\anaconda3\envs\yolov5\lib\site-packages\easyocr\easyocr.py in detect(self, img, min_size, text_threshold, low_text, link_threshold, canvas_size, mag_ratio, slope_ths, ycenter_ths, height_ths, width_ths, add_margin, reformat, optimal_num_chars)
#     273             img, img_cv_grey = reformat_input(img)
#     274
# --> 275         text_box_list = get_textbox(self.detector, img, canvas_size, mag_ratio,
#     276                                     text_threshold, link_threshold, low_text,
#     277                                     False, self.device, optimal_num_chars)
#
# c:\Users\hojun_window\anaconda3\envs\yolov5\lib\site-packages\easyocr\detection.py in get_textbox(detector, image, canvas_size, mag_ratio, text_threshold, link_threshold, low_text, poly, device, optimal_num_chars)
#      93     result = []
#      94     estimate_num_chars = optimal_num_chars is not None
# ---> 95     bboxes_list, polys_list = test_net(canvas_size, mag_ratio, detector,
#      96                                        image, text_threshold,
#      97                                        link_threshold, low_text, poly,
#
# c:\Users\hojun_window\anaconda3\envs\yolov5\lib\site-packages\easyocr\detection.py in test_net(canvas_size, mag_ratio, net, image, text_threshold, link_threshold, low_text, poly, device, estimate_num_chars)
#      49     for out in y:
#      50         # make score and link map
# ---> 51         score_text = out[:, :, 0].cpu().data.numpy()
#      52         score_link = out[:, :, 1].cpu().data.numpy()
#      53
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
